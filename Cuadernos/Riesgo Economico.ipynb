# %%
import pandas as pd

# %% [markdown]
# ## PIB

# %%
#cargamos el primer indicador
df_pib = pd.read_csv("/Users/rodri/Desktop/Proyecto final/Datos/Indicadores economicos/Crecimiento_PIB.csv")
df_pib
# Out:
#                                           Series Name        Series Code  \
# 0                               GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 1                               GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 2                               GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 3                               GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 4                               GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# ..                                                ...                ...
# 266                                               NaN                NaN
# 267                                               NaN                NaN
# 268                                               NaN                NaN
# 269  Data from database: World Development Indicators                NaN
# 270                          Last Updated: 06/28/2024                NaN
#
#        Country Name Country Code      2013 [YR2013]     2014 [YR2014]  \
# ...

# %%
#borramos columna
df_pib.drop(columns= "Series Code", inplace= True)
df_pib.head()
# Out:
#              Series Name    Country Name Country Code      2013 [YR2013]  \
# 0  GDP growth (annual %)     Afghanistan          AFG   5.60074465863221
# 1  GDP growth (annual %)         Albania          ALB   1.00201754071108
# 2  GDP growth (annual %)         Algeria          DZA   2.60000000006077
# 3  GDP growth (annual %)  American Samoa          ASM               -2.5
# 4  GDP growth (annual %)         Andorra          AND  -3.54759651549344
#
#       2014 [YR2014]     2015 [YR2015]      2016 [YR2016]      2017 [YR2017]  \
# 0  2.72454336219565  1.45131466066431   2.26031420279821    2.6470032027451
# 1  1.77444885260394  2.21872637517804   3.31498068384137   3.80259872019053
# 2  4.10000000035542  3.19999999974922   3.89999999992476    1.5000000001012
# 3  1.76282051282051  3.14960629921259  -1.67938931297709  -6.98757763975155
# 4  2.50446552114518  1.43414039522716   3.70967806978986  0.346071889630295
#
#       2018 [YR2018]       2019 [YR2019]      2020 [YR2020]  \
# ...

# %%
#corroboramos lista de paises
df_pib["Country Name"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
# ...

# %%
#realizamos una lista con los paises detectados que no eran paises 
paises_eliminar = ['Africa Eastern and Southern', 'Africa Western and Central',
       'Arab World', 'Caribbean small states',
       'Central Europe and the Baltics', 'Early-demographic dividend',
       'East Asia & Pacific',
       'East Asia & Pacific (excluding high income)',
       'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
       'Europe & Central Asia',
       'Europe & Central Asia (excluding high income)',
       'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
       'Fragile and conflict affected situations',
       'Heavily indebted poor countries (HIPC)', 'High income',
       'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
       'IDA total', 'Late-demographic dividend',
       'Latin America & Caribbean',
       'Latin America & Caribbean (excluding high income)',
       'Latin America & the Caribbean (IDA & IBRD countries)',
       'Least developed countries: UN classification',
       'Low & middle income', 'Low income', 'Lower middle income','Middle East & North Africa',
       'Middle East & North Africa (excluding high income)',
       'Middle East & North Africa (IDA & IBRD countries)',
       'Middle income', 'North America', 'Not classified', 'OECD members',
       'Other small states', 'Pacific island small states',
       'Post-demographic dividend', 'Pre-demographic dividend',
       'Small states', 'South Asia', 'South Asia (IDA & IBRD)',
       'Sub-Saharan Africa', 'Sub-Saharan Africa (excluding high income)',
       'Sub-Saharan Africa (IDA & IBRD countries)', 'Upper middle income',
       'World']

# %%
#generamos un df nuevo con los valores unicos que eran paises 
df_pib=df_pib[~df_pib["Country Name"].isin(paises_eliminar)]
df_pib
# Out:
#                                           Series Name    Country Name  \
# 0                               GDP growth (annual %)     Afghanistan
# 1                               GDP growth (annual %)         Albania
# 2                               GDP growth (annual %)         Algeria
# 3                               GDP growth (annual %)  American Samoa
# 4                               GDP growth (annual %)         Andorra
# ..                                                ...             ...
# 266                                               NaN             NaN
# 267                                               NaN             NaN
# 268                                               NaN             NaN
# 269  Data from database: World Development Indicators             NaN
# 270                          Last Updated: 06/28/2024             NaN
#
#     Country Code      2013 [YR2013]     2014 [YR2014]     2015 [YR2015]  \
# ...

# %%
#corroboramos que se haya hecho bien el cambio 
df_pib["Country Name"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
# ...

# %%
df_pib["Country Name"].nunique()
# Out:
# 217

# %%
#borramos paises que son Nans
df_pib.drop([270,269,268,267,266],axis=0, inplace=True)
# Out:
# /var/folders/cy/4jtvxlld09qd1srrzgj8fyy00000gp/T/ipykernel_24754/1764825177.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pib.drop([270,269,268,267,266],axis=0, inplace=True)

# %%
#corroboramos que no haya Nans
df_pib.isnull().sum()
# Out:
# Series Name      0
# Country Name     0
# Country Code     0
# 2013 [YR2013]    0
# 2014 [YR2014]    0
# 2015 [YR2015]    0
# 2016 [YR2016]    0
# 2017 [YR2017]    0
# 2018 [YR2018]    0
# 2019 [YR2019]    0
# 2020 [YR2020]    0
# 2021 [YR2021]    0
# 2022 [YR2022]    0
# 2023 [YR2023]    0
# dtype: int64

# %%
#borramos columna
df_pib.drop(columns = ["Country Code"], inplace=True)
# Out:
# /var/folders/cy/4jtvxlld09qd1srrzgj8fyy00000gp/T/ipykernel_24754/3990423366.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pib.drop(columns = ["Country Code"], inplace=True)

# %%
#realizamos una funcion para limpiar las columnas
def limpiar_nombres_columnas(df):
    df.columns = df.columns.str.replace(r'\s*\[.*\]$', '', regex=True)
    return df

# %%
#aplicamos funcion
df_pib = limpiar_nombres_columnas(df_pib)
df_pib
# Out:
#                Series Name           Country Name               2013  \
# 0    GDP growth (annual %)            Afghanistan   5.60074465863221
# 1    GDP growth (annual %)                Albania   1.00201754071108
# 2    GDP growth (annual %)                Algeria   2.60000000006077
# 3    GDP growth (annual %)         American Samoa               -2.5
# 4    GDP growth (annual %)                Andorra  -3.54759651549344
# ..                     ...                    ...                ...
# 212  GDP growth (annual %)  Virgin Islands (U.S.)  -6.28515529469308
# 213  GDP growth (annual %)     West Bank and Gaza   4.69856986552234
# 214  GDP growth (annual %)            Yemen, Rep.   4.82351906650533
# 215  GDP growth (annual %)                 Zambia   5.05753694179522
# 216  GDP growth (annual %)               Zimbabwe    3.1967308868621
#
#                    2014                2015               2016  \
# 0      2.72454336219565    1.45131466066431   2.26031420279821
# ...

# %%
#detectamos que habia paises que contenian valores con puntos suspensivos

# %%
# corroboramos que paises son
df_faltantes = df_pib[df_pib.eq('..').any(axis=1)]

paises_con_faltantes = df_faltantes['Country Name'].unique()
paises_con_faltantes
# Out:
# array(['Afghanistan', 'American Samoa', 'Aruba', 'Bermuda', 'Bhutan',
#        'British Virgin Islands', 'Cayman Islands', 'Channel Islands',
#        'Cuba', 'Curacao', 'Djibouti', 'Eritrea', 'Faroe Islands',
#        'French Polynesia', 'Gibraltar', 'Greenland', 'Guam',
#        'Isle of Man', "Korea, Dem. People's Rep.", 'Liechtenstein',
#        'Monaco', 'New Caledonia', 'Northern Mariana Islands', 'Qatar',
#        'San Marino', 'South Sudan', 'St. Martin (French part)',
#        'Syrian Arab Republic', 'Tonga', 'Venezuela, RB',
#        'Virgin Islands (U.S.)', 'Yemen, Rep.'], dtype=object)

# %%
# creamos un nuevo df sin los paises que contenian esos valores
df_pib = df_pib[~df_pib['Country Name'].isin(paises_con_faltantes)]
df_pib
# Out:
#                Series Name         Country Name                2013  \
# 1    GDP growth (annual %)              Albania    1.00201754071108
# 2    GDP growth (annual %)              Algeria    2.60000000006077
# 4    GDP growth (annual %)              Andorra   -3.54759651549344
# 5    GDP growth (annual %)               Angola    4.95461303112738
# 6    GDP growth (annual %)  Antigua and Barbuda  -0.600715511931753
# ..                     ...                  ...                 ...
# 209  GDP growth (annual %)              Vanuatu   0.463390415135095
# 211  GDP growth (annual %)             Viet Nam    5.55351081026072
# 213  GDP growth (annual %)   West Bank and Gaza    4.69856986552234
# 215  GDP growth (annual %)               Zambia    5.05753694179522
# 216  GDP growth (annual %)             Zimbabwe     3.1967308868621
#
#                    2014               2015               2016  \
# 1      1.77444885260394   2.21872637517804   3.31498068384137
# ...

# %%
#reseteamos el index, con un drop para que no se duplique e inplace para guardarlo
df_pib.reset_index(drop=True,inplace=True)

# %%
# giramos el df para futuros analisis
df_pib = pd.melt(df_pib, id_vars=['Country Name'], var_name='Año', value_name='Crecimiento_GDP(%)')

df_pib
# Out:
#              Country Name          Año     Crecimiento_GDP(%)
# 0                 Albania  Series Name  GDP growth (annual %)
# 1                 Algeria  Series Name  GDP growth (annual %)
# 2                 Andorra  Series Name  GDP growth (annual %)
# 3                  Angola  Series Name  GDP growth (annual %)
# 4     Antigua and Barbuda  Series Name  GDP growth (annual %)
# ...                   ...          ...                    ...
# 2215              Vanuatu         2023       2.21294177094788
# 2216             Viet Nam         2023       5.04643073618749
# 2217   West Bank and Gaza         2023      -5.50879437160218
# 2218               Zambia         2023       5.83247413510912
# 2219             Zimbabwe         2023       4.95578170349711
#
# [2220 rows x 3 columns]

# %%
#detectamos que duplico valores que no queremos 
df_pib["Año"].value_counts()
# Out:
# Año
# Series Name    185
# 2013           185
# 2014           185
# 2015           185
# 2016           185
# 2017           185
# 2018           185
# 2019           185
# 2020           185
# 2021           185
# 2022           185
# 2023           185
# Name: count, dtype: int64

# %%
#generamos un nuevo df sin estos valores que se duplicaron y no nos interesan
df_pib = df_pib[df_pib['Año'] != 'Series Name']

# %%
#corroboramos valores
df_pib["Año"].value_counts()
# Out:
# Año
# 2013    185
# 2014    185
# 2015    185
# 2016    185
# 2017    185
# 2018    185
# 2019    185
# 2020    185
# 2021    185
# 2022    185
# 2023    185
# Name: count, dtype: int64

# %%
#resetamos el index
df_pib.reset_index(drop=True,inplace=True)
df_pib
# Out:
#              Country Name   Año  Crecimiento_GDP(%)
# 0                 Albania  2013    1.00201754071108
# 1                 Algeria  2013    2.60000000006077
# 2                 Andorra  2013   -3.54759651549344
# 3                  Angola  2013    4.95461303112738
# 4     Antigua and Barbuda  2013  -0.600715511931753
# ...                   ...   ...                 ...
# 2030              Vanuatu  2023    2.21294177094788
# 2031             Viet Nam  2023    5.04643073618749
# 2032   West Bank and Gaza  2023   -5.50879437160218
# 2033               Zambia  2023    5.83247413510912
# 2034             Zimbabwe  2023    4.95578170349711
#
# [2035 rows x 3 columns]

# %%
#guardamos en el ordenador
df_pib.to_csv("df_pib_limpio.csv",index=False)

# %%
df_pib.dtypes
# Out:
# Country Name          object
# Año                   object
# Crecimiento_GDP(%)    object
# dtype: object

# %%
df_pib["Crecimiento_GDP(%)"]=df_pib["Crecimiento_GDP(%)"].astype(float)
# Out:
# /var/folders/cy/4jtvxlld09qd1srrzgj8fyy00000gp/T/ipykernel_24754/3858662460.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pib["Crecimiento_GDP(%)"]=df_pib["Crecimiento_GDP(%)"].astype(float)

# %%
df_pib.dtypes
# Out:
# Country Name           object
# Año                    object
# Crecimiento_GDP(%)    float64
# dtype: object

# %%
df_pib["Country Name"].nunique()
# Out:
# 185

# %%
df_pib
# Out:
#              Country Name   Año  Crecimiento_GDP(%)
# 0                 Albania  2013            1.002018
# 1                 Algeria  2013            2.600000
# 2                 Andorra  2013           -3.547597
# 3                  Angola  2013            4.954613
# 4     Antigua and Barbuda  2013           -0.600716
# ...                   ...   ...                 ...
# 2030              Vanuatu  2023            2.212942
# 2031             Viet Nam  2023            5.046431
# 2032   West Bank and Gaza  2023           -5.508794
# 2033               Zambia  2023            5.832474
# 2034             Zimbabwe  2023            4.955782
#
# [2035 rows x 3 columns]

# %%
df_pib["Country Name"].unique()
# Out:
# array(['Albania', 'Algeria', 'Andorra', 'Angola', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas, The', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cyprus', 'Czechia',
#        'Denmark', 'Dominica', 'Dominican Republic', 'Ecuador',
#        'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Fiji', 'Finland', 'France', 'Gabon',
#        'Gambia, The', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Grenada',
# ...

# %%
mapeo_paises = {
    "Albania": "Albania",
    "Algeria": "Argelia",
    "Andorra": "Andorra",
    "Angola": "Angola",
    "Antigua and Barbuda": "Antigua y Barbuda",
    "Argentina": "Argentina",
    "Armenia": "Armenia",
    "Australia": "Australia",
    "Austria": "Austria",
    "Azerbaijan": "Azerbaiyán",
    "Bahamas, The": "Bahamas",
    "Bahrain": "Bahrein",
    "Bangladesh": "Bangladesh",
    "Barbados": "Barbados",
    "Belarus": "Belarús",
    "Belgium": "Bélgica",
    "Belize": "Belice",
    "Benin": "Benin",
    "Bolivia": "Bolivia",
    "Bosnia and Herzegovina": "Bosnia y Herzegovina",
    "Botswana": "Botswana",
    "Brazil": "Brasil",
    "Brunei Darussalam": "Brunei Darussalam",
    "Bulgaria": "Bulgaria",
    "Burkina Faso": "Burkina Faso",
    "Burundi": "Burundi",
    "Cabo Verde": "Cabo Verde",
    "Cambodia": "Camboya",
    "Cameroon": "Camerún",
    "Canada": "Canadá",
    "Central African Republic": "República Centroafricana",
    "Chad": "Chad",
    "Chile": "Chile",
    "China": "China",
    "Colombia": "Colombia",
    "Comoros": "Comoras",
    "Congo, Dem. Rep.": "República Democrática del Congo",
    "Congo, Rep.": "República del Congo",
    "Costa Rica": "Costa Rica",
    "Cote d'Ivoire": "Côte d'Ivoire",
    "Croatia": "Croacia",
    "Cyprus": "Chipre",
    "Czechia": "Chequia",
    "Denmark": "Dinamarca",
    "Dominica": "Dominica",
    "Dominican Republic": "República Dominicana",
    "Ecuador": "Ecuador",
    "Egypt, Arab Rep.": "Egipto",
    "El Salvador": "El Salvador",
    "Equatorial Guinea": "Guinea Ecuatorial",
    "Estonia": "Estonia",
    "Eswatini": "Eswatini",
    "Ethiopia": "Etiopía",
    "Fiji": "Fiji",
    "Finland": "Finlandia",
    "France": "Francia",
    "Gabon": "Gabón",
    "Gambia, The": "Gambia",
    "Georgia": "Georgia",
    "Germany": "Alemania",
    "Ghana": "Ghana",
    "Greece": "Grecia",
    "Grenada": "Granada",
    "Guatemala": "Guatemala",
    "Guinea": "Guinea",
    "Guinea-Bissau": "Guinea-Bissau",
    "Guyana": "Guyana",
    "Haiti": "Haití",
    "Honduras": "Honduras",
    "Hong Kong SAR, China": "Hong Kong",
    "Hungary": "Hungría",
    "Iceland": "Islandia",
    "India": "India",
    "Indonesia": "Indonesia",
    "Iran, Islamic Rep.": "Irán",
    "Iraq": "Iraq",
    "Ireland": "Irlanda",
    "Israel": "Israel",
    "Italy": "Italia",
    "Jamaica": "Jamaica",
    "Japan": "Japón",
    "Jordan": "Jordania",
    "Kazakhstan": "Kazajstán",
    "Kenya": "Kenya",
    "Kiribati": "Kiribati",
    "Korea, Rep.": "Corea del Sur",
    "Kosovo": "Kosovo",
    "Kuwait": "Kuwait",
    "Kyrgyz Republic": "Kirguistán",
    "Lao PDR": "República Democrática Popular Lao",
    "Latvia": "Letonia",
    "Lebanon": "Líbano",
    "Lesotho": "Lesotho",
    "Liberia": "Liberia",
    "Libya": "Libia",
    "Lithuania": "Lituania",
    "Luxembourg": "Luxemburgo",
    "Macao SAR, China": "Región Administrativa Especial de Macao",
    "Madagascar": "Madagascar",
    "Malawi": "Malawi",
    "Malaysia": "Malasia",
    "Maldives": "Maldivas",
    "Mali": "Malí",
    "Malta": "Malta",
    "Marshall Islands": "Islas Marshall",
    "Mauritania": "Mauritania",
    "Mauritius": "Mauricio",
    "Mexico": "México",
    "Micronesia, Fed. Sts.": "Micronesia",
    "Moldova": "Moldova",
    "Mongolia": "Mongolia",
    "Montenegro": "Montenegro",
    "Morocco": "Marruecos",
    "Mozambique": "Mozambique",
    "Myanmar": "Myanmar",
    "Namibia": "Namibia",
    "Nauru": "Nauru",
    "Nepal": "Nepal",
    "Netherlands": "Países Bajos",
    "New Zealand": "Nueva Zelandia",
    "Nicaragua": "Nicaragua",
    "Niger": "Níger",
    "Nigeria": "Nigeria",
    "North Macedonia": "Macedonia del Norte",
    "Norway": "Noruega",
    "Oman": "Omán",
    "Pakistan": "Pakistán",
    "Palau": "Palau",
    "Panama": "Panamá",
    "Papua New Guinea": "Papua Nueva Guinea",
    "Paraguay": "Paraguay",
    "Peru": "Perú",
    "Philippines": "Filipinas",
    "Poland": "Polonia",
    "Portugal": "Portugal",
    "Puerto Rico": "Puerto Rico",
    "Romania": "Rumania",
    "Russian Federation": "Federación de Rusia",
    "Rwanda": "Rwanda",
    "Samoa": "Samoa",
    "Sao Tome and Principe": "Santo Tomé y Príncipe",
    "Saudi Arabia": "Arabia Saudita",
    "Senegal": "Senegal",
    "Serbia": "Serbia",
    "Seychelles": "Seychelles",
    "Sierra Leone": "Sierra Leona",
    "Singapore": "Singapur",
    "Sint Maarten (Dutch part)": "Sint Maarten (Dutch part)",
    "Slovak Republic": "República Eslovaca",
    "Slovenia": "Eslovenia",
    "Solomon Islands": "Islas Salomón",
    "Somalia": "Somalia",
    "South Africa": "Sudáfrica",
    "Spain": "España",
    "Sri Lanka": "Sri Lanka",
    "St. Kitts and Nevis": "Saint Kitts y Nevis",
    "St. Lucia": "Santa Lucía",
    "St. Vincent and the Grenadines": "San Vicente y las Granadinas",
    "Sudan": "Sudán",
    "Suriname": "Suriname",
    "Sweden": "Suecia",
    "Switzerland": "Suiza",
    "Tajikistan": "Tayikistán",
    "Tanzania": "Tanzania",
    "Thailand": "Tailandia",
    "Timor-Leste": "Timor-Leste",
    "Togo": "Togo",
    "Trinidad and Tobago": "Trinidad y Tobago",
    "Tunisia": "Túnez",
    "Turkiye": "Turquía",
    "Turkmenistan": "Turkmenistán",
    "Turks and Caicos Islands": "Islas Turcas y Caicos",
    "Tuvalu": "Tuvalu",
    "Uganda": "Uganda",
    "Ukraine": "Ucrania",
    "United Arab Emirates": "Emiratos Árabes Unidos",
    "United Kingdom": "Reino Unido",
    "United States": "Estados Unidos",
    "Uruguay": "Uruguay",
    "Uzbekistan": "Uzbekistán",
    "Vanuatu": "Vanuatu",
    "Viet Nam": "Viet Nam",
    "West Bank and Gaza": "Ribera Occidental y Gaza",
    "Zambia": "Zambia",
    "Zimbabwe": "Zimbabwe"
}

df_pib['Country Name'] = df_pib['Country Name'].replace(mapeo_paises)
# Out:
# /var/folders/cy/4jtvxlld09qd1srrzgj8fyy00000gp/T/ipykernel_24754/112309686.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pib['Country Name'] = df_pib['Country Name'].replace(mapeo_paises)

# %%
df_pib.to_csv("df_pib_limpio.csv",index=False)

# %%
df_pib.sort_values(by=["Country Name", "Año"], inplace=True)
# Out:
# /var/folders/cy/4jtvxlld09qd1srrzgj8fyy00000gp/T/ipykernel_24754/3769358850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pib.sort_values(by=["Country Name", "Año"], inplace=True)

# %%
df_pib
# Out:
#      Country Name   Año  Crecimiento_GDP(%)
# 0         Albania  2013            1.002018
# 185       Albania  2014            1.774449
# 370       Albania  2015            2.218726
# 555       Albania  2016            3.314981
# 740       Albania  2017            3.802599
# ...           ...   ...                 ...
# 1294     Zimbabwe  2019           -6.332446
# 1479     Zimbabwe  2020           -7.816951
# 1664     Zimbabwe  2021            8.468017
# 1849     Zimbabwe  2022            6.522375
# 2034     Zimbabwe  2023            4.955782
#
# [2035 rows x 3 columns]

# %%
df_pib.dtypes
# Out:
# Country Name           object
# Año                    object
# Crecimiento_GDP(%)    float64
# dtype: object

# %% [markdown]
# ## INFLACION

# %%
#cargamos el df
df_inflacion = pd.read_csv("/Users/rodri/Desktop/Proyecto final/Datos/Indicadores economicos/Inflacion.csv")
df_inflacion
# Out:
#                                           Series Name     Series Code  \
# 0               Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG
# 1               Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG
# 2               Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG
# 3               Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG
# 4               Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG
# ..                                                ...             ...
# 266                                               NaN             NaN
# 267                                               NaN             NaN
# 268                                               NaN             NaN
# 269  Data from database: World Development Indicators             NaN
# 270                          Last Updated: 06/28/2024             NaN
#
#        Country Name Country Code     2013 [YR2013]     2014 [YR2014]  \
# ...

# %%
#eliminamos columnas que no nos interesaban
df_inflacion.drop(["Series Code","Country Code","Series Name"],axis=1, inplace=True)
df_inflacion
# Out:
#        Country Name     2013 [YR2013]     2014 [YR2014]      2015 [YR2015]  \
# 0       Afghanistan  7.38577178397855  4.67399603536305  -0.66170916471352
# 1           Albania  1.93762080205229   1.6258650440261   1.89617402592365
# 2           Algeria  3.25423910998847  2.91692692067458   4.78444700693889
# 3    American Samoa                ..                ..                 ..
# 4           Andorra                ..                ..                 ..
# ..              ...               ...               ...                ...
# 266             NaN               NaN               NaN                NaN
# 267             NaN               NaN               NaN                NaN
# 268             NaN               NaN               NaN                NaN
# 269             NaN               NaN               NaN                NaN
# 270             NaN               NaN               NaN                NaN
#
# ...

# %%
#aplicamos funcion de limpmieza de columnas
limpiar_nombres_columnas(df_inflacion)
df_inflacion
# Out:
#        Country Name              2013              2014               2015  \
# 0       Afghanistan  7.38577178397855  4.67399603536305  -0.66170916471352
# 1           Albania  1.93762080205229   1.6258650440261   1.89617402592365
# 2           Algeria  3.25423910998847  2.91692692067458   4.78444700693889
# 3    American Samoa                ..                ..                 ..
# 4           Andorra                ..                ..                 ..
# ..              ...               ...               ...                ...
# 266             NaN               NaN               NaN                NaN
# 267             NaN               NaN               NaN                NaN
# 268             NaN               NaN               NaN                NaN
# 269             NaN               NaN               NaN                NaN
# 270             NaN               NaN               NaN                NaN
#
# ...

# %%
#miramos que paises tenemos 
df_inflacion["Country Name"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
# ...

# %%
#hacemos una lista de los no paises y creamos un nuevo df sin ellos 
no_paises= ['Africa Eastern and Southern', 'Africa Western and Central',
       'Arab World', 'Caribbean small states',
       'Central Europe and the Baltics', 'Early-demographic dividend',
       'East Asia & Pacific',
       'East Asia & Pacific (excluding high income)',
       'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
       'Europe & Central Asia',
       'Europe & Central Asia (excluding high income)',
       'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
       'Fragile and conflict affected situations',
       'Heavily indebted poor countries (HIPC)', 'High income',
       'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
       'IDA total', 'Late-demographic dividend',
       'Latin America & Caribbean',
       'Latin America & Caribbean (excluding high income)',
       'Latin America & the Caribbean (IDA & IBRD countries)',
       'Least developed countries: UN classification',
       'Low & middle income', 'Low income', 'Lower middle income',
       'Middle East & North Africa',
       'Middle East & North Africa (excluding high income)',
       'Middle East & North Africa (IDA & IBRD countries)',
       'Middle income', 'North America', 'Not classified', 'OECD members',
       'Other small states', 'Pacific island small states',
       'Post-demographic dividend', 'Pre-demographic dividend',
       'Small states', 'South Asia', 'South Asia (IDA & IBRD)',
       'Sub-Saharan Africa', 'Sub-Saharan Africa (excluding high income)',
       'Sub-Saharan Africa (IDA & IBRD countries)', 'Upper middle income',
       'World']

df_inflacion=df_inflacion[~df_inflacion["Country Name"].isin(no_paises)]
df_inflacion
# Out:
#        Country Name              2013              2014               2015  \
# 0       Afghanistan  7.38577178397855  4.67399603536305  -0.66170916471352
# 1           Albania  1.93762080205229   1.6258650440261   1.89617402592365
# 2           Algeria  3.25423910998847  2.91692692067458   4.78444700693889
# 3    American Samoa                ..                ..                 ..
# 4           Andorra                ..                ..                 ..
# ..              ...               ...               ...                ...
# 266             NaN               NaN               NaN                NaN
# 267             NaN               NaN               NaN                NaN
# 268             NaN               NaN               NaN                NaN
# 269             NaN               NaN               NaN                NaN
# 270             NaN               NaN               NaN                NaN
#
# ...

# %%
#corroboramos que no haya nulls
df_inflacion.isnull().sum()
# Out:
# Country Name    5
# 2013            5
# 2014            5
# 2015            5
# 2016            5
# 2017            5
# 2018            5
# 2019            5
# 2020            5
# 2021            5
# 2022            5
# 2023            5
# dtype: int64

# %%
#borramos filas nans
df_inflacion.dropna(inplace=True)
#volvemos a corroborar nulls
df_inflacion.isnull().sum()
# Out:
# /var/folders/cy/4jtvxlld09qd1srrzgj8fyy00000gp/T/ipykernel_24754/3009192197.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_inflacion.dropna(inplace=True)
# Country Name    0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# 2022            0
# 2023            0
# dtype: int64

# %%
#detectamos si habia paises con datos faltantes que no eran nulls
df_faltantes = df_inflacion[df_inflacion.eq('..').any(axis=1)]
#agregamos a una lista
paises_con_faltantes = df_faltantes['Country Name'].unique()
paises_con_faltantes
# Out:
# array(['Afghanistan', 'Albania', 'American Samoa', 'Andorra', 'Argentina',
#        'Aruba', 'Barbados', 'Bermuda', 'Bosnia and Herzegovina',
#        'British Virgin Islands', 'Cabo Verde', 'Cayman Islands',
#        'Channel Islands', 'Comoros', 'Congo, Dem. Rep.', 'Cuba',
#        'Curacao', 'Equatorial Guinea', 'Eritrea', 'Eswatini',
#        'Faroe Islands', 'Fiji', 'French Polynesia', 'Gibraltar',
#        'Greenland', 'Guam', 'Guinea-Bissau', 'Iraq', 'Isle of Man',
#        'Kiribati', "Korea, Dem. People's Rep.", 'Liberia',
#        'Liechtenstein', 'Macao SAR, China', 'Maldives',
#        'Marshall Islands', 'Micronesia, Fed. Sts.', 'Monaco', 'Myanmar',
#        'Nauru', 'New Caledonia', 'Northern Mariana Islands',
#        'Puerto Rico', 'Russian Federation', 'San Marino', 'Senegal',
#        'Seychelles', 'Sint Maarten (Dutch part)', 'Somalia',
#        'St. Martin (French part)', 'Sudan', 'Suriname',
#        'Syrian Arab Republic', 'Tajikistan', 'Timor-Leste', 'Togo',
# ...

# %%
df_inflacion["Country Name"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
# ...

# %%
array1 =['Albania', 'Algeria', 'Andorra', 'Angola', 'Antigua and Barbuda',
       'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan',
       'Bahamas, The', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
       'Belgium', 'Belize', 'Benin', 'Bolivia', 'Bosnia and Herzegovina',
       'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria',
       'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
       'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
       'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
       'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cyprus', 'Czechia',
       'Denmark', 'Dominica', 'Dominican Republic', 'Ecuador',
       'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Estonia',
       'Eswatini', 'Ethiopia', 'Fiji', 'Finland', 'France', 'Gabon',
       'Gambia, The', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Grenada',
       'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
       'Honduras', 'Hong Kong SAR, China', 'Hungary', 'Iceland', 'India',
       'Indonesia', 'Iran, Islamic Rep.', 'Iraq', 'Ireland', 'Israel',
       'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya',
       'Kiribati', 'Korea, Rep.', 'Kosovo', 'Kuwait', 'Kyrgyz Republic',
       'Lao PDR', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya',
       'Lithuania', 'Luxembourg', 'Macao SAR, China', 'Madagascar',
       'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
       'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico',
       'Micronesia, Fed. Sts.', 'Moldova', 'Mongolia', 'Montenegro',
       'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal',
       'Netherlands', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria',
       'North Macedonia', 'Norway', 'Oman', 'Pakistan', 'Palau', 'Panama',
       'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland',
       'Portugal', 'Puerto Rico', 'Romania', 'Russian Federation',
       'Rwanda', 'Samoa', 'Sao Tome and Principe', 'Saudi Arabia',
       'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore',
       'Sint Maarten (Dutch part)', 'Slovak Republic', 'Slovenia',
       'Solomon Islands', 'Somalia', 'South Africa', 'Spain', 'Sri Lanka',
       'St. Kitts and Nevis', 'St. Lucia',
       'St. Vincent and the Grenadines', 'Sudan', 'Suriname', 'Sweden',
       'Switzerland', 'Tajikistan', 'Tanzania', 'Thailand', 'Timor-Leste',
       'Togo', 'Trinidad and Tobago', 'Tunisia', 'Turkiye',
       'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda',
       'Ukraine', 'United Arab Emirates', 'United Kingdom',
       'United States', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Viet Nam',
       'West Bank and Gaza', 'Zambia', 'Zimbabwe']

array2=['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
       'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
       'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
       'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
       'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
       'Botswana', 'Brazil', 'British Virgin Islands',
       'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
       'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
       'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
       'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
       'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
       'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica',
       'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
       'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia',
       'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Polynesia',
       'Gabon', 'Gambia, The', 'Georgia', 'Germany', 'Ghana', 'Gibraltar',
       'Greece', 'Greenland', 'Grenada', 'Guam', 'Guatemala', 'Guinea',
       'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras',
       'Hong Kong SAR, China', 'Hungary', 'Iceland', 'India', 'Indonesia',
       'Iran, Islamic Rep.', 'Iraq', 'Ireland', 'Isle of Man', 'Israel',
       'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya',
       'Kiribati', "Korea, Dem. People's Rep.", 'Korea, Rep.', 'Kosovo',
       'Kuwait', 'Kyrgyz Republic', 'Lao PDR', 'Latvia', 'Lebanon',
       'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania',
       'Luxembourg', 'Macao SAR, China', 'Madagascar', 'Malawi',
       'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands',
       'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Fed. Sts.',
       'Moldova', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco',
       'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal',
       'Netherlands', 'New Caledonia', 'New Zealand', 'Nicaragua',
       'Niger', 'Nigeria', 'North Macedonia', 'Northern Mariana Islands',
       'Norway', 'Oman', 'Pakistan', 'Palau', 'Panama',
       'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland',
       'Portugal', 'Puerto Rico', 'Qatar', 'Romania',
       'Russian Federation', 'Rwanda', 'Samoa', 'San Marino',
       'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
       'Seychelles', 'Sierra Leone', 'Singapore',
       'Sint Maarten (Dutch part)', 'Slovak Republic', 'Slovenia',
       'Solomon Islands', 'Somalia', 'South Africa', 'South Sudan',
       'Spain', 'Sri Lanka', 'St. Kitts and Nevis', 'St. Lucia',
       'St. Martin (French part)', 'St. Vincent and the Grenadines',
       'Sudan', 'Suriname', 'Sweden', 'Switzerland',
       'Syrian Arab Republic', 'Tajikistan', 'Tanzania', 'Thailand',
       'Timor-Leste', 'Togo', 'Tonga', 'Trinidad and Tobago', 'Tunisia',
       'Turkiye', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu',
       'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom',
       'United States', 'Uruguay', 'Uzbekistan', 'Vanuatu',
       'Venezuela, RB', 'Viet Nam', 'Virgin Islands (U.S.)',
       'West Bank and Gaza', 'Yemen, Rep.', 'Zambia', 'Zimbabwe']

# Encontramos los países que están en ambos arrays
coincidencias = list(set(array1) & set(array2))

# Imprimimos la cantidad de países coincidentes
print(f"Cantidad de países coincidentes: {len(coincidencias)}")
# Out:
# Cantidad de países coincidentes: 185

# %%
# nos quedamos con los valores coincidentes
df_inflacion = df_inflacion[df_inflacion['Country Name'].isin(coincidencias)]
df_inflacion['Country Name'].nunique()
# Out:
# 185

# %%
#Agregamos valores faltantes
df_inflacion.at[1,"2023"] = df_inflacion.at[1, "2023"].replace("..", "4.8")
df_inflacion.at[216,"2023"] = df_inflacion.at[216, "2023"].replace("..", "172.2")
df_inflacion.at[209,"2023"] = df_inflacion.at[209, "2023"].replace("..", "14.4")
df_inflacion.at[16,"2020"] = df_inflacion.at[16, "2020"].replace("..", "6.6")
df_inflacion.at[16,"2021"] = df_inflacion.at[16, "2021"].replace("..", "5.4")
df_inflacion.at[16,"2022"] = df_inflacion.at[16, "2022"].replace("..", "18.2")
df_inflacion.at[7,"2013"] = df_inflacion.at[7, "2013"].replace("..", "18.4")
df_inflacion.at[7,"2014"] = df_inflacion.at[7, "2014"].replace("..", "38")
df_inflacion.at[7,"2015"] = df_inflacion.at[7, "2015"].replace("..", "26.7")
df_inflacion.at[7,"2016"] = df_inflacion.at[7, "2016"].replace("..", "41.2")
df_inflacion.at[7,"2017"] = df_inflacion.at[7, "2017"].replace("..", "27.7")
df_inflacion.at[7,"2018"] = df_inflacion.at[2, "2018"].replace("..", "34.3")
df_inflacion.at[7,"2019"] = df_inflacion.at[7, "2019"].replace("..", "53.5")
df_inflacion.at[7,"2020"] = df_inflacion.at[7, "2020"].replace("..", "42")
df_inflacion.at[7,"2021"] = df_inflacion.at[7, "2021"].replace("..", "48.4")
df_inflacion.at[7,"2022"] = df_inflacion.at[7, "2022"].replace("..", "72.4")
df_inflacion.at[7,"2023"] = df_inflacion.at[7, "2023"].replace("..", "133.49")
df_inflacion.at[4,"2013"] = df_inflacion.at[4, "2013"].replace("..", "0.5")
df_inflacion.at[4,"2014"] = df_inflacion.at[4, "2014"].replace("..", "-0.1")
df_inflacion.at[4,"2015"] = df_inflacion.at[4, "2015"].replace("..", "-1.1")
df_inflacion.at[4,"2016"] = df_inflacion.at[4, "2016"].replace("..", "-0.4")
df_inflacion.at[4,"2017"] = df_inflacion.at[4, "2017"].replace("..", "2.6")
df_inflacion.at[4,"2018"] = df_inflacion.at[4, "2018"].replace("..", "1.3")
df_inflacion.at[4,"2019"] = df_inflacion.at[4, "2019"].replace("..", "0.7")
df_inflacion.at[4,"2020"] = df_inflacion.at[4, "2020"].replace("..", "0.3")
df_inflacion.at[4,"2021"] = df_inflacion.at[4, "2021"].replace("..", "1.7")
df_inflacion.at[4,"2022"] = df_inflacion.at[4, "2022"].replace("..", "7.2")
df_inflacion.at[4,"2023"] = df_inflacion.at[4, "2023"].replace("..", "4.6")
df_inflacion.at[24,"2013"] = df_inflacion.at[24, "2013"].replace("..", "-0.1")
df_inflacion.at[24,"2014"] = df_inflacion.at[24, "2014"].replace("..", "-0.9")
df_inflacion.at[24,"2015"] = df_inflacion.at[24, "2015"].replace("..", "-1")
df_inflacion.at[24,"2016"] = df_inflacion.at[24, "2016"].replace("..", "-1.6")
df_inflacion.at[24,"2017"] = df_inflacion.at[24, "2017"].replace("..", "-0.8")
df_inflacion.at[24,"2018"] = df_inflacion.at[24, "2018"].replace("..", "1.4")
df_inflacion.at[24,"2019"] = df_inflacion.at[24, "2019"].replace("..", "0.6")
df_inflacion.at[24,"2020"] = df_inflacion.at[24, "2020"].replace("..", "-1.1")
df_inflacion.at[24,"2021"] = df_inflacion.at[24, "2021"].replace("..", "2")
df_inflacion.at[24,"2022"] = df_inflacion.at[24, "2022"].replace("..", "14")
df_inflacion.at[24,"2023"] = df_inflacion.at[24, "2023"].replace("..", "6.1")
df_inflacion.at[32,"2023"] = df_inflacion.at[32, "2023"].replace("..", "3.7")
df_inflacion.at[43,"2014"] = df_inflacion.at[43, "2014"].replace("..", "-0.9")
df_inflacion.at[43,"2015"] = df_inflacion.at[43, "2015"].replace("..", "2.7")
df_inflacion.at[43,"2016"] = df_inflacion.at[43, "2016"].replace("..", "-1.4")
df_inflacion.at[43,"2017"] = df_inflacion.at[43, "2017"].replace("..", "1.4")
df_inflacion.at[43,"2018"] = df_inflacion.at[43, "2018"].replace("..", "6.3")
df_inflacion.at[43,"2019"] = df_inflacion.at[43, "2019"].replace("..", "6.3")
df_inflacion.at[43,"2020"] = df_inflacion.at[43, "2020"].replace("..", "-4.8")
df_inflacion.at[43,"2021"] = df_inflacion.at[43, "2021"].replace("..", "7.1")
df_inflacion.at[43,"2022"] = df_inflacion.at[43, "2022"].replace("..", "20.6")
df_inflacion.at[43,"2023"] = df_inflacion.at[43, "2023"].replace("..", "-2")
df_inflacion.at[44,"2017"] = df_inflacion.at[44, "2017"].replace("..", "35.7")
df_inflacion.at[44,"2018"] = df_inflacion.at[44, "2018"].replace("..", "29.3")
df_inflacion.at[44,"2019"] = df_inflacion.at[44, "2019"].replace("..", "4.7")
df_inflacion.at[44,"2020"] = df_inflacion.at[44, "2020"].replace("..", "11.4")
df_inflacion.at[44,"2021"] = df_inflacion.at[44, "2021"].replace("..", "9")
df_inflacion.at[44,"2022"] = df_inflacion.at[44, "2022"].replace("..", "9.3")
df_inflacion.at[44,"2023"] = df_inflacion.at[44, "2023"].replace("..", "19.9")
df_inflacion.at[161,"2022"] = df_inflacion.at[44, "2022"].replace("..", "13.8")
df_inflacion.at[161,"2023"] = df_inflacion.at[161, "2023"].replace("..", "5.9")
df_inflacion.at[167,"2023"] = df_inflacion.at[167, "2023"].replace("..", "5")
df_inflacion.at[169,"2021"] = df_inflacion.at[169, "2021"].replace("..", "24.2")
df_inflacion.at[169,"2022"] = df_inflacion.at[169, "2022"].replace("..", "27.5")
df_inflacion.at[169,"2023"] = df_inflacion.at[169, "2023"].replace("..", "26.2")
df_inflacion.at[176,"2013"] = df_inflacion.at[176, "2013"].replace("..", "-1.3")
df_inflacion.at[176,"2014"] = df_inflacion.at[176, "2014"].replace("..", "0")
df_inflacion.at[176,"2015"] = df_inflacion.at[176, "2015"].replace("..", "0.3")
df_inflacion.at[176,"2016"] = df_inflacion.at[176, "2016"].replace("..", "1.5")
df_inflacion.at[176,"2017"] = df_inflacion.at[176, "2017"].replace("..", "7.7")
df_inflacion.at[176,"2018"] = df_inflacion.at[176, "2018"].replace("..", "11.2")
df_inflacion.at[176,"2019"] = df_inflacion.at[176, "2019"].replace("..", "14.6")
df_inflacion.at[176,"2020"] = df_inflacion.at[176, "2020"].replace("..", "20.2")
df_inflacion.at[176,"2021"] = df_inflacion.at[176, "2021"].replace("..", "27")
df_inflacion.at[176,"2022"] = df_inflacion.at[176, "2022"].replace("..", "34.7")
df_inflacion.at[176,"2023"] = df_inflacion.at[176, "2023"].replace("..", "43.6")
df_inflacion.at[176,"2013"] = df_inflacion.at[176, "2013"].replace("..", "-1.3")
df_inflacion.at[176,"2014"] = df_inflacion.at[176, "2014"].replace("..", "0")
df_inflacion.at[176,"2015"] = df_inflacion.at[176, "2015"].replace("..", "0.3")
df_inflacion.at[176,"2016"] = df_inflacion.at[176, "2016"].replace("..", "1.5")
df_inflacion.at[176,"2017"] = df_inflacion.at[176, "2017"].replace("..", "7.7")
df_inflacion.at[176,"2018"] = df_inflacion.at[176, "2018"].replace("..", "11.2")
df_inflacion.at[176,"2019"] = df_inflacion.at[176, "2019"].replace("..", "14.6")
df_inflacion.at[176,"2020"] = df_inflacion.at[176, "2020"].replace("..", "20.2")
df_inflacion.at[176,"2021"] = df_inflacion.at[176, "2021"].replace("..", "27")
df_inflacion.at[176,"2022"] = df_inflacion.at[176, "2022"].replace("..", "34.7")
df_inflacion.at[176,"2023"] = df_inflacion.at[176, "2023"].replace("..", "43.6")
df_inflacion.at[185,"2023"] = df_inflacion.at[185, "2023"].replace("..", "172")
df_inflacion.at[186,"2018"] = df_inflacion.at[186, "2018"].replace("..", "7.1")
df_inflacion.at[186,"2019"] = df_inflacion.at[186, "2019"].replace("..", "4.3")
df_inflacion.at[186,"2023"] = df_inflacion.at[186, "2023"].replace("..", "51.6")
df_inflacion.at[190,"2017"] = df_inflacion.at[190, "2017"].replace("..", "7.3")
df_inflacion.at[190,"2018"] = df_inflacion.at[190, "2018"].replace("..", "3.9")
df_inflacion.at[190,"2019"] = df_inflacion.at[190, "2019"].replace("..", "7.8")
df_inflacion.at[190,"2020"] = df_inflacion.at[190, "2020"].replace("..", "8.6")
df_inflacion.at[190,"2021"] = df_inflacion.at[190, "2021"].replace("..", "9")
df_inflacion.at[190,"2022"] = df_inflacion.at[190, "2022"].replace("..", "6.6")
df_inflacion.at[190,"2023"] = df_inflacion.at[190, "2023"].replace("..", "3.7")
df_inflacion.at[204,"2023"] = df_inflacion.at[204, "2023"].replace("..", "1.62")

# %%
#resetamos index
df_inflacion.reset_index(drop=True,inplace=True)

# %%
#agregamos valores faltantes
df_inflacion.at[51,"2023"] = df_inflacion.at[51, "2023"].replace("..", "2.5")
df_inflacion.at[53,"2020"] = df_inflacion.at[53, "2020"].replace("..", "3.9")
df_inflacion.at[53,"2021"] = df_inflacion.at[53, "2021"].replace("..", "3.7")
df_inflacion.at[53,"2022"] = df_inflacion.at[53, "2022"].replace("..", "4.8")
df_inflacion.at[53,"2023"] = df_inflacion.at[53, "2023"].replace("..", "5.5")
df_inflacion.at[55,"2023"] = df_inflacion.at[55, "2023"].replace("..", "2.3")
df_inflacion.at[67,"2023"] = df_inflacion.at[67, "2023"].replace("..", "7.2")
df_inflacion.at[77,"2023"] = df_inflacion.at[77, "2023"].replace("..", "4.4")
df_inflacion.at[86,"2022"] = df_inflacion.at[86, "2022"].replace("..", "4.9")
df_inflacion.at[86,"2023"] = df_inflacion.at[86, "2023"].replace("..", "8.3")
df_inflacion.at[95,"2019"] = df_inflacion.at[95, "2019"].replace("..", "352.2")
df_inflacion.at[95,"2020"] = df_inflacion.at[95, "2020"].replace("..", "428.9")
df_inflacion.at[95,"2021"] = df_inflacion.at[95, "2021"].replace("..", "470.2")
df_inflacion.at[95,"2022"] = df_inflacion.at[95, "2022"].replace("..", "513.5")
df_inflacion.at[95,"2023"] = df_inflacion.at[95, "2023"].replace("..", "575.5")
df_inflacion.at[99,"2023"] = df_inflacion.at[99, "2023"].replace("..", "0.9")
df_inflacion.at[103,"2023"] = df_inflacion.at[103, "2023"].replace("..", "2.9")
df_inflacion.at[106,"2013"] = df_inflacion.at[106, "2013"].replace("..", "2.3")
df_inflacion.at[106,"2014"] = df_inflacion.at[106, "2014"].replace("..", "3.8")
df_inflacion.at[106,"2015"] = df_inflacion.at[106, "2015"].replace("..", "-11.1")
df_inflacion.at[106,"2016"] = df_inflacion.at[106, "2016"].replace("..", "-2.3")
df_inflacion.at[106,"2017"] = df_inflacion.at[106, "2017"].replace("..", "3.1")
df_inflacion.at[106,"2018"] = df_inflacion.at[106, "2018"].replace("..", "2.2")
df_inflacion.at[106,"2019"] = df_inflacion.at[106, "2019"].replace("..", "-5.1")
df_inflacion.at[106,"2020"] = df_inflacion.at[106, "2020"].replace("..", "4.9")
df_inflacion.at[106,"2021"] = df_inflacion.at[106, "2021"].replace("..", "9")
df_inflacion.at[106,"2022"] = df_inflacion.at[106, "2022"].replace("..", "8.6")
df_inflacion.at[106,"2023"] = df_inflacion.at[106, "2023"].replace("..", "6.8")
df_inflacion.at[116,"2020"] = df_inflacion.at[116, "2020"].replace("..", "3.8")
df_inflacion.at[116,"2021"] = df_inflacion.at[116, "2021"].replace("..", "6.2")
df_inflacion.at[116,"2022"] = df_inflacion.at[116, "2022"].replace("..", "7.5")
df_inflacion.at[116,"2023"] = df_inflacion.at[116, "2023"].replace("..", "2.5")
df_inflacion.at[118,"2013"] = df_inflacion.at[116, "2013"].replace("..", "-1.1")
df_inflacion.at[118,"2014"] = df_inflacion.at[116, "2014"].replace("..", "0.3")
df_inflacion.at[118,"2015"] = df_inflacion.at[116, "2015"].replace("..", "9.8")
df_inflacion.at[118,"2016"] = df_inflacion.at[116, "2016"].replace("..", "8.2")
df_inflacion.at[118,"2017"] = df_inflacion.at[116, "2017"].replace("..", "5.1")
df_inflacion.at[118,"2018"] = df_inflacion.at[116, "2018"].replace("..", "-14.4")
df_inflacion.at[118,"2019"] = df_inflacion.at[116, "2019"].replace("..", "4.2")
df_inflacion.at[118,"2020"] = df_inflacion.at[116, "2020"].replace("..", "1.9")
df_inflacion.at[118,"2021"] = df_inflacion.at[116, "2021"].replace("..", "1.1")
df_inflacion.at[118,"2022"] = df_inflacion.at[116, "2022"].replace("..", "1.5")
df_inflacion.at[118,"2023"] = df_inflacion.at[116, "2023"].replace("..", "5.2")
df_inflacion.at[137,"2013"] = df_inflacion.at[137, "2013"].replace("..", "1.2")
df_inflacion.at[137,"2014"] = df_inflacion.at[137, "2014"].replace("..", "0.9")
df_inflacion.at[137,"2015"] = df_inflacion.at[137, "2015"].replace("..", "-0.3")
df_inflacion.at[137,"2016"] = df_inflacion.at[137, "2016"].replace("..", "-0.2")
df_inflacion.at[137,"2017"] = df_inflacion.at[137, "2017"].replace("..", "0.6")
df_inflacion.at[137,"2018"] = df_inflacion.at[137, "2018"].replace("..", "1.6")
df_inflacion.at[137,"2019"] = df_inflacion.at[137, "2019"].replace("..", "0.5")
df_inflacion.at[137,"2020"] = df_inflacion.at[137, "2020"].replace("..", "0")
df_inflacion.at[137,"2021"] = df_inflacion.at[137, "2021"].replace("..", "0.2")
df_inflacion.at[137,"2022"] = df_inflacion.at[137, "2022"].replace("..", "4.7")
df_inflacion.at[137,"2023"] = df_inflacion.at[137, "2023"].replace("..", "5.4")
df_inflacion.at[169,"2020"] = df_inflacion.at[169, "2020"].replace("..", "0.5")
df_inflacion.at[169,"2021"] = df_inflacion.at[169, "2021"].replace("..", "3.8")
df_inflacion.at[169,"2022"] = df_inflacion.at[169, "2022"].replace("..", "7")
df_inflacion.at[169,"2023"] = df_inflacion.at[169, "2023"].replace("..", "8.4")
df_inflacion.at[175,"2013"] = df_inflacion.at[175, "2013"].replace("..", "6.8")
df_inflacion.at[175,"2014"] = df_inflacion.at[175, "2014"].replace("..", "6")
df_inflacion.at[175,"2015"] = df_inflacion.at[175, "2015"].replace("..", "7.4")
df_inflacion.at[175,"2016"] = df_inflacion.at[175, "2016"].replace("..", "3.6")
df_inflacion.at[175,"2017"] = df_inflacion.at[175, "2017"].replace("..", "8")
df_inflacion.at[175,"2018"] = df_inflacion.at[175, "2018"].replace("..", "13.3")
df_inflacion.at[175,"2019"] = df_inflacion.at[175, "2019"].replace("..", "5.1")
df_inflacion.at[175,"2020"] = df_inflacion.at[175, "2020"].replace("..", "6.1")
df_inflacion.at[175,"2021"] = df_inflacion.at[175, "2021"].replace("..", "19.5")
df_inflacion.at[175,"2022"] = df_inflacion.at[175, "2022"].replace("..", "11.2")
df_inflacion.at[175,"2023"] = df_inflacion.at[175, "2023"].replace("..", "5.9")
df_inflacion.at[184,"2023"] = df_inflacion.at[184, "2023"].replace("..", "11.8")

# %%
#corroboramos cuantos valores faltantes quedan
df_faltantes = df_inflacion[df_inflacion.eq('..').any(axis=1)]

paises_con_faltantes = df_faltantes['Country Name'].unique()
paises_con_faltantes
# Out:
# array(['Equatorial Guinea', 'Eswatini', 'Guinea-Bissau', 'Iraq',
#        'Kiribati', 'Liberia', 'Macao SAR, China', 'Maldives',
#        'Marshall Islands', 'Micronesia, Fed. Sts.', 'Myanmar', 'Nauru',
#        'Puerto Rico', 'Sint Maarten (Dutch part)', 'Timor-Leste', 'Togo',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uzbekistan'],
#       dtype=object)

# %%
# nos quedamos solo con los paises que contienen valores
df_inflacion = df_inflacion[~df_inflacion['Country Name'].isin(paises_con_faltantes)]
df_inflacion
# Out:
#             Country Name              2013               2014  \
# 0                Albania  1.93762080205229    1.6258650440261
# 1                Algeria  3.25423910998847   2.91692692067458
# 2                Andorra               0.5               -0.1
# 3                 Angola  8.77781429332624   7.28038730361121
# 4    Antigua and Barbuda  1.05949782356169   1.08944157435355
# ..                   ...               ...                ...
# 180              Vanuatu  1.45893371757921  0.798863838097023
# 181             Viet Nam  6.59267475899192   4.08455446637617
# 182   West Bank and Gaza  1.72439933626931   1.73298510037447
# 183               Zambia  6.97767605490307   7.80687553566333
# 184             Zimbabwe  1.63495041543822  -0.19778481012661
#
#                   2015                2016               2017  \
# 0     1.89617402592365     1.2754316836741   1.98666133171199
# 1     4.78444700693889    6.39769480268757   5.59111590961664
# ...

# %%
#resetamos index
df_inflacion.reset_index(drop=True,inplace=True)

# %%
# modificamos la disposicion de las columnas para mejor visibilidad y posterior analisis
df_inflacion = pd.melt(df_inflacion, id_vars=['Country Name'], var_name='Año', value_name='Inflacion Anual(%)')

df_inflacion
# Out:
#              Country Name   Año Inflacion Anual(%)
# 0                 Albania  2013   1.93762080205229
# 1                 Algeria  2013   3.25423910998847
# 2                 Andorra  2013                0.5
# 3                  Angola  2013   8.77781429332624
# 4     Antigua and Barbuda  2013   1.05949782356169
# ...                   ...   ...                ...
# 1810              Vanuatu  2023               14.4
# 1811             Viet Nam  2023   3.25289282667662
# 1812   West Bank and Gaza  2023   5.87110177678988
# 1813               Zambia  2023    10.884531691282
# 1814             Zimbabwe  2023              172.2
#
# [1815 rows x 3 columns]

# %%
df_inflacion["Country Name"].value_counts()
# Out:
# Country Name
# Albania        11
# Namibia        11
# Netherlands    11
# New Zealand    11
# Nicaragua      11
#                ..
# Georgia        11
# Germany        11
# Ghana          11
# Greece         11
# Zimbabwe       11
# Name: count, Length: 165, dtype: int64

# %%
df_inflacion["Country Name"].nunique()
# Out:
# 165

# %%
df_inflacion.to_csv("df_inflacion_limpio.csv",index=False)

# %%
df_inflacion.dtypes
# Out:
# Country Name          object
# Año                   object
# Inflacion Anual(%)    object
# dtype: object

# %%
df_inflacion["Inflacion Anual(%)"]=df_inflacion["Inflacion Anual(%)"].astype(float)

# %%
df_inflacion["Country Name"].nunique()
# Out:
# 165

# %%
df_inflacion
# Out:
#              Country Name   Año  Inflacion Anual(%)
# 0                 Albania  2013            1.937621
# 1                 Algeria  2013            3.254239
# 2                 Andorra  2013            0.500000
# 3                  Angola  2013            8.777814
# 4     Antigua and Barbuda  2013            1.059498
# ...                   ...   ...                 ...
# 1810              Vanuatu  2023           14.400000
# 1811             Viet Nam  2023            3.252893
# 1812   West Bank and Gaza  2023            5.871102
# 1813               Zambia  2023           10.884532
# 1814             Zimbabwe  2023          172.200000
#
# [1815 rows x 3 columns]

# %%
df_inflacion["Country Name"].unique()
# Out:
# array(['Albania', 'Algeria', 'Andorra', 'Angola', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas, The', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cyprus', 'Czechia',
#        'Denmark', 'Dominica', 'Dominican Republic', 'Ecuador',
#        'Egypt, Arab Rep.', 'El Salvador', 'Estonia', 'Ethiopia', 'Fiji',
#        'Finland', 'France', 'Gabon', 'Gambia, The', 'Georgia', 'Germany',
#        'Ghana', 'Greece', 'Grenada', 'Guatemala', 'Guinea', 'Guyana',
# ...

# %%
mapeo_paises = {
    "Albania": "Albania",
    "Algeria": "Argelia",
    "Andorra": "Andorra",
    "Angola": "Angola",
    "Antigua and Barbuda": "Antigua y Barbuda",
    "Argentina": "Argentina",
    "Armenia": "Armenia",
    "Australia": "Australia",
    "Austria": "Austria",
    "Azerbaijan": "Azerbaiyán",
    "Bahamas, The": "Bahamas",
    "Bahrain": "Bahrein",
    "Bangladesh": "Bangladesh",
    "Barbados": "Barbados",
    "Belarus": "Bielorrusia",
    "Belgium": "Bélgica",
    "Belize": "Belice",
    "Benin": "Benín",
    "Bolivia": "Bolivia",
    "Bosnia and Herzegovina": "Bosnia y Herzegovina",
    "Botswana": "Botsuana",
    "Brazil": "Brasil",
    "Brunei Darussalam": "Brunei Darussalam",
    "Bulgaria": "Bulgaria",
    "Burkina Faso": "Burkina Faso",
    "Burundi": "Burundi",
    "Cabo Verde": "Cabo Verde",
    "Cambodia": "Camboya",
    "Cameroon": "Camerún",
    "Canada": "Canadá",
    "Central African Republic": "República Centroafricana",
    "Chad": "Chad",
    "Chile": "Chile",
    "China": "China",
    "Colombia": "Colombia",
    "Comoros": "Comoras",
    "Congo, Dem. Rep.": "República Democrática del Congo",
    "Congo, Rep.": "República del Congo",
    "Costa Rica": "Costa Rica",
    "Cote d'Ivoire": "Costa de Marfil",
    "Croatia": "Croacia",
    "Cyprus": "Chipre",
    "Czechia": "Chequia",
    "Denmark": "Dinamarca",
    "Dominica": "Dominica",
    "Dominican Republic": "República Dominicana",
    "Ecuador": "Ecuador",
    "Egypt, Arab Rep.": "Egipto",
    "El Salvador": "El Salvador",
    "Estonia": "Estonia",
    "Ethiopia": "Etiopía",
    "Fiji": "Fiyi",
    "Finland": "Finlandia",
    "France": "Francia",
    "Gabon": "Gabón",
    "Gambia, The": "Gambia",
    "Georgia": "Georgia",
    "Germany": "Alemania",
    "Ghana": "Ghana",
    "Greece": "Grecia",
    "Grenada": "Granada",
    "Guatemala": "Guatemala",
    "Guinea": "Guinea",
    "Guyana": "Guyana",
    "Haiti": "Haití",
    "Honduras": "Honduras",
    "Hong Kong SAR, China": "Hong Kong",
    "Hungary": "Hungría",
    "Iceland": "Islandia",
    "India": "India",
    "Indonesia": "Indonesia",
    "Iran, Islamic Rep.": "Irán",
    "Ireland": "Irlanda",
    "Israel": "Israel",
    "Italy": "Italia",
    "Jamaica": "Jamaica",
    "Japan": "Japón",
    "Jordan": "Jordania",
    "Kazakhstan": "Kazajistán",
    "Kenya": "Kenia",
    "Korea, Rep.": "Corea del Sur",
    "Kosovo": "Kosovo",
    "Kuwait": "Kuwait",
    "Kyrgyz Republic": "Kirguistán",
    "Lao PDR": "Laos",
    "Latvia": "Letonia",
    "Lebanon": "Líbano",
    "Lesotho": "Lesoto",
    "Libya": "Libia",
    "Lithuania": "Lituania",
    "Luxembourg": "Luxemburgo",
    "Madagascar": "Madagascar",
    "Malawi": "Malaui",
    "Malaysia": "Malasia",
    "Mali": "Malí",
    "Malta": "Malta",
    "Mauritania": "Mauritania",
    "Mauritius": "Mauricio",
    "Mexico": "México",
    "Moldova": "Moldavia",
    "Mongolia": "Mongolia",
    "Montenegro": "Montenegro",
    "Morocco": "Marruecos",
    "Mozambique": "Mozambique",
    "Namibia": "Namibia",
    "Nepal": "Nepal",
    "Netherlands": "Países Bajos",
    "New Zealand": "Nueva Zelanda",
    "Nicaragua": "Nicaragua",
    "Niger": "Níger",
    "Nigeria": "Nigeria",
    "North Macedonia": "Macedonia del Norte",
    "Norway": "Noruega",
    "Oman": "Omán",
    "Pakistan": "Pakistán",
    "Palau": "Palaos",
    "Panama": "Panamá",
    "Papua New Guinea": "Papúa Nueva Guinea",
    "Paraguay": "Paraguay",
    "Peru": "Perú",
    "Philippines": "Filipinas",
    "Poland": "Polonia",
    "Portugal": "Portugal",
    "Romania": "Rumania",
    "Russian Federation": "Rusia",
    "Rwanda": "Ruanda",
    "Samoa": "Samoa",
    "Sao Tome and Principe": "Santo Tomé y Príncipe",
    "Saudi Arabia": "Arabia Saudita",
    "Senegal": "Senegal",
    "Serbia": "Serbia",
    "Seychelles": "Seychelles",
    "Sierra Leone": "Sierra Leona",
    "Singapore": "Singapur",
    "Slovak Republic": "Eslovaquia",
    "Slovenia": "Eslovenia",
    "Solomon Islands": "Islas Salomón",
    "Somalia": "Somalia",
    "South Africa": "Sudáfrica",
    "Spain": "España",
    "Sri Lanka": "Sri Lanka",
    "St. Kitts and Nevis": "San Cristóbal y Nieves",
    "St. Lucia": "Santa Lucía",
    "St. Vincent and the Grenadines": "San Vicente y las Granadinas",
    "Sudan": "Sudán",
    "Suriname": "Surinam",
    "Sweden": "Suecia",
    "Switzerland": "Suiza",
    "Tajikistan": "Tayikistán",
    "Tanzania": "Tanzania",
    "Thailand": "Tailandia",
    "Trinidad and Tobago": "Trinidad y Tobago",
    "Tunisia": "Túnez",
    "Turkiye": "Turquía",
    "Uganda": "Uganda",
    "Ukraine": "Ucrania",
    "United Arab Emirates": "Emiratos Árabes Unidos",
    "United Kingdom": "Reino Unido",
    "United States": "Estados Unidos",
    "Uruguay": "Uruguay",
    "Vanuatu": "Vanuatu",
    "Viet Nam": "Vietnam",
    "West Bank and Gaza": "Cisjordania y Gaza",
    "Zambia": "Zambia",
    "Zimbabwe": "Zimbabue"
}

df_inflacion['Country Name'] = df_inflacion['Country Name'].replace(mapeo_paises)

# %%
df_inflacion.to_csv("df_inflacion_limpio.csv",index=False)

# %%
df_inflacion.sort_values(by=["Country Name", "Año"], inplace=True)

# %%
df_inflacion
# Out:
#      Country Name   Año  Inflacion Anual(%)
# 0         Albania  2013            1.937621
# 165       Albania  2014            1.625865
# 330       Albania  2015            1.896174
# 495       Albania  2016            1.275432
# 660       Albania  2017            1.986661
# ...           ...   ...                 ...
# 1154     Zimbabue  2019          255.304991
# 1319     Zimbabue  2020          557.201817
# 1484     Zimbabue  2021           98.546105
# 1649     Zimbabue  2022          104.705171
# 1814     Zimbabue  2023          172.200000
#
# [1815 rows x 3 columns]

# %%
df_inflacion.dtypes
# Out:
# Country Name           object
# Año                    object
# Inflacion Anual(%)    float64
# dtype: object

# %% [markdown]
# ## BALANZA COMERCIAL

# %%
df_balanza = pd.read_csv("/Users/rodri/Desktop/Proyecto final/Datos/Indicadores economicos/balanza_comercial.csv")
df_balanza
# Out:
#              País Balanza_comercial    %PIB   Año
# 0          España        -43.500,6    -2,98  2023
# 1        Alemania        223.602,9     5,42  2023
# 2     Reino Unido       -250.264,8    -8,10  2023
# 3         Francia       -127.266,9    -4,51  2023
# 4          Italia         34.373,0     1,65  2023
# ...           ...               ...     ...   ...
# 2099        Samoa           -229,3   -38,15  2013
# 2100        Yemen         -4.625,5   -15,20  2013
# 2101    Sudáfrica        -22.721,6    -7,53  2013
# 2102       Zambia             15,5     0,07  2013
# 2103     Zimbabue         -2.491,8   -17,33  2013
#
# [2104 rows x 4 columns]

# %%
df_balanza["País"].unique()
# Out:
# array(['España', 'Alemania', 'Reino Unido', 'Francia', 'Italia',
#        'Portugal', 'Estados Unidos', 'Japón', 'China', 'Andorra',
#        'Emiratos Árabes Unidos', 'Afganistán', 'Antigua y Barbuda',
#        'Albania', 'Armenia', 'Angola', 'Argentina', 'Austria',
#        'Australia', 'Azerbaiyán', 'Bosnia y Herzegovina', 'Barbados',
#        'Bangladés', 'Bélgica', 'Burkina Faso', 'Bulgaria', 'Baréin',
#        'Burundi', 'Benin', 'Brunéi', 'Bolivia', 'Brasil', 'Bahamas',
#        'Bután', 'Botsuana', 'Bielorrusia', 'Belice', 'Canadá',
#        'República Democrática del Congo', 'República Centroafricana',
#        'República del Congo', 'Suiza', 'Costa de Marfil', 'Chile',
#        'Camerún', 'Colombia', 'Costa Rica', 'Cuba', 'Cabo Verde',
#        'Chipre', 'Chequia', 'Yibuti', 'Dinamarca', 'Dominica',
#        'República Dominicana', 'Argelia', 'Ecuador', 'Estonia', 'Egipto',
#        'Eritrea', 'Etiopía', 'Finlandia', 'Fiyi',
# ...

# %%
# realizamos un mapeo para traducirlo al español y poder ver cuantos paises coinciden y cuales son
mapping = {
    'España': 'Spain',
    'Alemania': 'Germany',
    'Reino Unido': 'United Kingdom',
    'Francia': 'France',
    'Italia': 'Italy',
    'Portugal': 'Portugal',
    'Estados Unidos': 'United States',
    'Japón': 'Japan',
    'China': 'China',
    'Andorra': 'Andorra',
    'Emiratos Árabes Unidos': 'United Arab Emirates',
    'Afganistán': 'Afghanistan',
    'Antigua y Barbuda': 'Antigua and Barbuda',
    'Albania': 'Albania',
    'Armenia': 'Armenia',
    'Angola': 'Angola',
    'Argentina': 'Argentina',
    'Austria': 'Austria',
    'Australia': 'Australia',
    'Azerbaiyán': 'Azerbaijan',
    'Bosnia y Herzegovina': 'Bosnia and Herzegovina',
    'Barbados': 'Barbados',
    'Bangladés': 'Bangladesh',
    'Bélgica': 'Belgium',
    'Burkina Faso': 'Burkina Faso',
    'Bulgaria': 'Bulgaria',
    'Baréin': 'Bahrain',
    'Burundi': 'Burundi',
    'Benin': 'Benin',
    'Brunéi': 'Brunei Darussalam',
    'Bolivia': 'Bolivia',
    'Brasil': 'Brazil',
    'Bahamas': 'Bahamas, The',
    'Bután': 'Bhutan',
    'Botsuana': 'Botswana',
    'Bielorrusia': 'Belarus',
    'Belice': 'Belize',
    'Canadá': 'Canada',
    'República Democrática del Congo': 'Congo, Dem. Rep.',
    'República Centroafricana': 'Central African Republic',
    'República del Congo': 'Congo, Rep.',
    'Suiza': 'Switzerland',
    'Costa de Marfil': "Cote d'Ivoire",
    'Chile': 'Chile',
    'Camerún': 'Cameroon',
    'Colombia': 'Colombia',
    'Costa Rica': 'Costa Rica',
    'Cuba': 'Cuba',
    'Cabo Verde': 'Cabo Verde',
    'Chipre': 'Cyprus',
    'Chequia': 'Czechia',
    'Yibuti': 'Djibouti',
    'Dinamarca': 'Denmark',
    'Dominica': 'Dominica',
    'República Dominicana': 'Dominican Republic',
    'Argelia': 'Algeria',
    'Ecuador': 'Ecuador',
    'Estonia': 'Estonia',
    'Egipto': 'Egypt, Arab Rep.',
    'Eritrea': 'Eritrea',
    'Etiopía': 'Ethiopia',
    'Finlandia': 'Finland',
    'Fiyi': 'Fiji',
    'Estados Federados de Micronesia': 'Micronesia, Fed. Sts.',
    'Gabón': 'Gabon',
    'Granada': 'Grenada',
    'Georgia': 'Georgia',
    'Ghana': 'Ghana',
    'Gambia': 'Gambia, The',
    'Guinea': 'Guinea',
    'Guinea Ecuatorial': 'Equatorial Guinea',
    'Grecia': 'Greece',
    'Guatemala': 'Guatemala',
    'Guinea-Bisáu': 'Guinea-Bissau',
    'Guyana': 'Guyana',
    'Hong Kong': 'Hong Kong SAR, China',
    'Honduras': 'Honduras',
    'Croacia': 'Croatia',
    'Haití': 'Haiti',
    'Hungría': 'Hungary',
    'Indonesia': 'Indonesia',
    'Irlanda': 'Ireland',
    'Israel': 'Israel',
    'India': 'India',
    'Irak': 'Iraq',
    'Irán': 'Iran, Islamic Rep.',
    'Islandia': 'Iceland',
    'Jamaica': 'Jamaica',
    'Jordania': 'Jordan',
    'Kenia': 'Kenya',
    'Kirguistán': 'Kyrgyz Republic',
    'Camboya': 'Cambodia',
    'Kiribati': 'Kiribati',
    'Comoras': 'Comoros',
    'San Cristóbal y Nieves': 'St. Kitts and Nevis',
    'Corea del Norte': 'Korea, Dem. People’s Rep.',
    'Corea del Sur': 'Korea, Rep.',
    'Kuwait': 'Kuwait',
    'Kazajistán': 'Kazakhstan',
    'Laos': 'Lao PDR',
    'Líbano': 'Lebanon',
    'Santa Lucía': 'St. Lucia',
    'Liechtenstein': 'Liechtenstein',
    'Sri Lanka': 'Sri Lanka',
    'Liberia': 'Liberia',
    'Lesoto': 'Lesotho',
    'Lituania': 'Lithuania',
    'Luxemburgo': 'Luxembourg',
    'Letonia': 'Latvia',
    'Libia': 'Libya',
    'Marruecos': 'Morocco',
    'Moldavia': 'Moldova',
    'Montenegro': 'Montenegro',
    'Madagascar': 'Madagascar',
    'Islas Marshall': 'Marshall Islands',
    'Macedonia del Norte': 'North Macedonia',
    'Malí': 'Mali',
    'Myanmar': 'Myanmar',
    'Mongolia': 'Mongolia',
    'Mauritania': 'Mauritania',
    'Malta': 'Malta',
    'Mauricio': 'Mauritius',
    'Maldivas': 'Maldives',
    'Malaui': 'Malawi',
    'México': 'Mexico',
    'Malasia': 'Malaysia',
    'Mozambique': 'Mozambique',
    'Namibia': 'Namibia',
    'Níger': 'Niger',
    'Nigeria': 'Nigeria',
    'Nicaragua': 'Nicaragua',
    'Países Bajos': 'Netherlands',
    'Noruega': 'Norway',
    'Nepal': 'Nepal',
    'Nauru': 'Nauru',
    'Nueva Zelanda': 'New Zealand',
    'Omán': 'Oman',
    'Panamá': 'Panama',
    'Perú': 'Peru',
    'Papúa Nueva Guinea': 'Papua New Guinea',
    'Filipinas': 'Philippines',
    'Pakistán': 'Pakistan',
    'Polonia': 'Poland',
    'Palaos': 'Palau',
    'Paraguay': 'Paraguay',
    'Catar': 'Qatar',
    'Rumanía': 'Romania',
    'Serbia': 'Serbia',
    'Rusia': 'Russian Federation',
    'Ruanda': 'Rwanda',
    'Arabia Saudita': 'Saudi Arabia',
    'Islas Salomón': 'Solomon Islands',
    'Seychelles': 'Seychelles',
    'Sudán': 'Sudan',
    'Suecia': 'Sweden',
    'Singapur': 'Singapore',
    'Eslovenia': 'Slovenia',
    'Eslovaquia': 'Slovak Republic',
    'Sierra Leona': 'Sierra Leone',
    'Senegal': 'Senegal',
    'Surinam': 'Suriname',
    'Sudán del Sur': 'South Sudan',
    'Santo Tomé y Príncipe': 'Sao Tome and Principe',
    'El Salvador': 'El Salvador',
    'Siria': 'Syrian Arab Republic',
    'Eswatini': 'Eswatini',
    'Chad': 'Chad',
    'Togo': 'Togo',
    'Tailandia': 'Thailand',
    'Tayikistán': 'Tajikistan',
    'Timor Oriental': 'Timor-Leste',
    'Turkmenistán': 'Turkmenistan',
    'Túnez': 'Tunisia',
    'Tonga': 'Tonga',
    'Türkiye': 'Turkey',
    'Trinidad y Tobago': 'Trinidad and Tobago',
    'Tuvalu': 'Tuvalu',
    'Taiwan': 'Taiwan, China',
    'Tanzania': 'Tanzania',
    'Ucrania': 'Ukraine',
    'Uganda': 'Uganda',
    'Uruguay': 'Uruguay',
    'Uzbekistán': 'Uzbekistan',
    'San Vicente y las Granadinas': 'St. Vincent and the Grenadines',
    'Venezuela': 'Venezuela, RB',
    'Viet Nam': 'Vietnam',
    'Vanuatu': 'Vanuatu',
    'Samoa': 'Samoa',
    'Yemen': 'Yemen, Rep.',
    'Sudáfrica': 'South Africa',
    'Zambia': 'Zambia',
    'Zimbabue': 'Zimbabwe',
}



array1_mapped = [mapping.get(country, country) for country in array1]


common_countries = set(array1_mapped).intersection(set(array2))

print(f"Hay {len(common_countries)} países en común.")
print("Los países en común son:")
print(common_countries)
# Out:
# Hay 184 países en común.
# Los países en común son:
# ...

# %%
# modificamos espacios, comas, puntos y tipo de dato para mejor visibilidad y posterior analisis.
df_balanza["Balanza_comercial"] = df_balanza["Balanza_comercial"].str.replace("\xa0", "").str.replace(".", "", regex=False).str.replace(" ", "").str.replace(",", ".").astype(float)

# %%
#idem con el porcentaje con respecto al PIB
df_balanza["%PIB"] = df_balanza["%PIB"].str.replace("\xa0", "").str.replace(".", "", regex=False).str.replace(" ", "").str.replace(",", ".").astype(float)

# %%
# cambiamos el tipo de dato de la columna año
df_balanza["Año"]=df_balanza["Año"].astype(object)

# %%
#cambiamos nombre de columna para unificar 
df_balanza = df_balanza.rename(columns={"País": "Country Name"})

# %%
df_balanza.dtypes
# Out:
# Country Name          object
# Balanza_comercial    float64
# %PIB                 float64
# Año                   object
# dtype: object

# %%
df_balanza.to_csv("df_balanza_limpio.csv",index= False)

# %%
df_balanza["Country Name"].nunique()
# Out:
# 192

# %%
df_balanza
# Out:
#      Country Name  Balanza_comercial   %PIB   Año
# 0          España           -43500.6  -2.98  2023
# 1        Alemania           223602.9   5.42  2023
# 2     Reino Unido          -250264.8  -8.10  2023
# 3         Francia          -127266.9  -4.51  2023
# 4          Italia            34373.0   1.65  2023
# ...           ...                ...    ...   ...
# 2099        Samoa             -229.3 -38.15  2013
# 2100        Yemen            -4625.5 -15.20  2013
# 2101    Sudáfrica           -22721.6  -7.53  2013
# 2102       Zambia               15.5   0.07  2013
# 2103     Zimbabue            -2491.8 -17.33  2013
#
# [2104 rows x 4 columns]

# %%
df_balanza["Country Name"].unique()
# Out:
# array(['España', 'Alemania', 'Reino Unido', 'Francia', 'Italia',
#        'Portugal', 'Estados Unidos', 'Japón', 'China', 'Andorra',
#        'Emiratos Árabes Unidos', 'Afganistán', 'Antigua y Barbuda',
#        'Albania', 'Armenia', 'Angola', 'Argentina', 'Austria',
#        'Australia', 'Azerbaiyán', 'Bosnia y Herzegovina', 'Barbados',
#        'Bangladés', 'Bélgica', 'Burkina Faso', 'Bulgaria', 'Baréin',
#        'Burundi', 'Benin', 'Brunéi', 'Bolivia', 'Brasil', 'Bahamas',
#        'Bután', 'Botsuana', 'Bielorrusia', 'Belice', 'Canadá',
#        'República Democrática del Congo', 'República Centroafricana',
#        'República del Congo', 'Suiza', 'Costa de Marfil', 'Chile',
#        'Camerún', 'Colombia', 'Costa Rica', 'Cuba', 'Cabo Verde',
#        'Chipre', 'Chequia', 'Yibuti', 'Dinamarca', 'Dominica',
#        'República Dominicana', 'Argelia', 'Ecuador', 'Estonia', 'Egipto',
#        'Eritrea', 'Etiopía', 'Finlandia', 'Fiyi',
# ...

# %%
mapeo_paises = {
    "Albania": "Albania",
    "Algeria": "Argelia",
    "Andorra": "Andorra",
    "Angola": "Angola",
    "Antigua and Barbuda": "Antigua y Barbuda",
    "Argentina": "Argentina",
    "Armenia": "Armenia",
    "Australia": "Australia",
    "Austria": "Austria",
    "Azerbaijan": "Azerbaiyán",
    "Bahamas, The": "Bahamas",
    "Bahrain": "Baréin",
    "Bangladesh": "Bangladés",
    "Barbados": "Barbados",
    "Belarus": "Bielorrusia",
    "Belgium": "Bélgica",
    "Belize": "Belice",
    "Benin": "Benin",
    "Bolivia": "Bolivia",
    "Bosnia and Herzegovina": "Bosnia y Herzegovina",
    "Botswana": "Botsuana",
    "Brazil": "Brasil",
    "Brunei Darussalam": "Brunéi",
    "Bulgaria": "Bulgaria",
    "Burkina Faso": "Burkina Faso",
    "Burundi": "Burundi",
    "Cabo Verde": "Cabo Verde",
    "Cambodia": "Camboya",
    "Cameroon": "Camerún",
    "Canada": "Canadá",
    "Central African Republic": "República Centroafricana",
    "Chad": "Chad",
    "Chile": "Chile",
    "China": "China",
    "Colombia": "Colombia",
    "Comoros": "Comoras",
    "Congo, Dem. Rep.": "República Democrática del Congo",
    "Congo, Rep.": "República del Congo",
    "Costa Rica": "Costa Rica",
    "Cote d'Ivoire": "Costa de Marfil",
    "Croatia": "Croacia",
    "Cyprus": "Chipre",
    "Czechia": "Chequia",
    "Denmark": "Dinamarca",
    "Dominica": "Dominica",
    "Dominican Republic": "República Dominicana",
    "Ecuador": "Ecuador",
    "Egypt, Arab Rep.": "Egipto",
    "El Salvador": "El Salvador",
    "Estonia": "Estonia",
    "Eswatini": "Eswatini",
    "Ethiopia": "Etiopía",
    "Fiji": "Fiyi",
    "Finland": "Finlandia",
    "France": "Francia",
    "Gabon": "Gabón",
    "Gambia, The": "Gambia",
    "Georgia": "Georgia",
    "Germany": "Alemania",
    "Ghana": "Ghana",
    "Greece": "Grecia",
    "Grenada": "Granada",
    "Guatemala": "Guatemala",
    "Guinea": "Guinea",
    "Guinea-Bissau": "Guinea-Bisáu",
    "Guyana": "Guyana",
    "Haiti": "Haití",
    "Honduras": "Honduras",
    "Hong Kong SAR, China": "Hong Kong",
    "Hungary": "Hungría",
    "Iceland": "Islandia",
    "India": "India",
    "Indonesia": "Indonesia",
    "Iran, Islamic Rep.": "Irán",
    "Iraq": "Irak",
    "Ireland": "Irlanda",
    "Israel": "Israel",
    "Italy": "Italia",
    "Jamaica": "Jamaica",
    "Japan": "Japón",
    "Jordan": "Jordania",
    "Kazakhstan": "Kazajistán",
    "Kenya": "Kenia",
    "Kiribati": "Kiribati",
    "Korea, Rep.": "Corea del Sur",
    "Kosovo": "Kosovo",
    "Kuwait": "Kuwait",
    "Kyrgyz Republic": "Kirguistán",
    "Lao PDR": "Laos",
    "Latvia": "Letonia",
    "Lebanon": "Líbano",
    "Lesotho": "Lesoto",
    "Libya": "Libia",
    "Lithuania": "Lituania",
    "Luxembourg": "Luxemburgo",
    "Madagascar": "Madagascar",
    "Malawi": "Malaui",
    "Malaysia": "Malasia",
    "Mali": "Malí",
    "Malta": "Malta",
    "Marshall Islands": "Islas Marshall",
    "Mauritania": "Mauritania",
    "Mauritius": "Mauricio",
    "Mexico": "México",
    "Micronesia, Fed. Sts.": "Estados Federados de Micronesia",
    "Moldova": "Moldavia",
    "Mongolia": "Mongolia",
    "Montenegro": "Montenegro",
    "Morocco": "Marruecos",
    "Mozambique": "Mozambique",
    "Myanmar": "Myanmar",
    "Namibia": "Namibia",
    "Nauru": "Nauru",
    "Nepal": "Nepal",
    "Netherlands": "Países Bajos",
    "New Zealand": "Nueva Zelanda",
    "Nicaragua": "Nicaragua",
    "Niger": "Níger",
    "Nigeria": "Nigeria",
    "North Macedonia": "Macedonia del Norte",
    "Norway": "Noruega",
    "Oman": "Omán",
    "Pakistan": "Pakistán",
    "Palau": "Palaos",
    "Panama": "Panamá",
    "Papua New Guinea": "Papúa Nueva Guinea",
    "Paraguay": "Paraguay",
    "Peru": "Perú",
    "Philippines": "Filipinas",
    "Poland": "Polonia",
    "Portugal": "Portugal",
    "Romania": "Rumanía",
    "Russian Federation": "Rusia",
    "Rwanda": "Ruanda",
    "Samoa": "Samoa",
    "Sao Tome and Principe": "Santo Tomé y Príncipe",
    "Saudi Arabia": "Arabia Saudita",
    "Senegal": "Senegal",
    "Serbia": "Serbia",
    "Seychelles": "Seychelles",
    "Sierra Leone": "Sierra Leona",
    "Singapore": "Singapur",
    "Sint Maarten (Dutch part)": "Sint Maarten",
    "Slovak Republic": "Eslovaquia",
    "Slovenia": "Eslovenia",
    "Solomon Islands": "Islas Salomón",
    "Somalia": "Somalia",
    "South Africa": "Sudáfrica",
    "Spain": "España",
    "Sri Lanka": "Sri Lanka",
    "St. Kitts and Nevis": "San Cristóbal y Nieves",
    "St. Lucia": "Santa Lucía",
    "St. Vincent and the Grenadines": "San Vicente y las Granadinas",
    "Sudan": "Sudán",
    "Suriname": "Surinam",
    "Sweden": "Suecia",
    "Switzerland": "Suiza",
    "Tajikistan": "Tayikistán",
    "Tanzania": "Tanzania",
    "Thailand": "Tailandia",
    "Timor-Leste": "Timor Oriental",
    "Togo": "Togo",
    "Trinidad and Tobago": "Trinidad y Tobago",
    "Tunisia": "Túnez",
    "Turkiye": "Türkiye",
    "Turkmenistan": "Turkmenistán",
    "Tuvalu": "Tuvalu",
    "Uganda": "Uganda",
    "Ukraine": "Ucrania",
    "United Arab Emirates": "Emiratos Árabes Unidos",
    "United Kingdom": "Reino Unido",
    "United States": "Estados Unidos",
    "Uruguay": "Uruguay",
    "Uzbekistan": "Uzbekistán",
    "Vanuatu": "Vanuatu",
    "Viet Nam": "Vietnam",
    "West Bank and Gaza": "Ribera Occidental y Gaza",
    "Zambia": "Zambia",
    "Zimbabwe": "Zimbabue"
}

df_balanza['Country Name'] = df_balanza['Country Name'].replace(mapeo_paises)

# %%
df_balanza.to_csv("df_balanza_limpio.csv",index=False)

# %%
df_balanza.sort_values(by=["Country Name", "Año"], inplace=True)

# %%
df_balanza
# Out:
#      Country Name  Balanza_comercial      %PIB   Año
# 1925   Afganistán            -6053.3    -39.86  2013
# 1735   Afganistán            -5388.6    -34.73  2014
# 1544   Afganistán            -6445.7    -35.66  2015
# 1353   Afganistán            -5364.3    -32.94  2016
# 1162   Afganistán            -5613.9    -33.57  2017
# ...           ...                ...       ...   ...
# 959      Zimbabue             -489.7     -2.38  2019
# 767      Zimbabue            -1092.9     -4.64  2020
# 575      Zimbabue            -1303.1     -4.29  2021
# 383      Zimbabue            -1963.1     -6.57  2022
# 191      Zimbabue            -1839.3 -26432.99  2023
#
# [2104 rows x 4 columns]

# %%
df_balanza.dtypes
# Out:
# Country Name          object
# Balanza_comercial    float64
# %PIB                 float64
# Año                   object
# dtype: object

# %% [markdown]
# ## RESERVAS INTERNACIONALES

# %%
df_reservas = pd.read_csv("/Users/rodri/Desktop/Proyecto final/Datos/Indicadores economicos/reservas_internac.csv")
df_reservas
# Out:
#                                           Series Name     Series Code  \
# 0         Total reserves (includes gold, current US$)  FI.RES.TOTL.CD
# 1         Total reserves (includes gold, current US$)  FI.RES.TOTL.CD
# 2         Total reserves (includes gold, current US$)  FI.RES.TOTL.CD
# 3         Total reserves (includes gold, current US$)  FI.RES.TOTL.CD
# 4         Total reserves (includes gold, current US$)  FI.RES.TOTL.CD
# ..                                                ...             ...
# 266                                               NaN             NaN
# 267                                               NaN             NaN
# 268                                               NaN             NaN
# 269  Data from database: World Development Indicators             NaN
# 270                          Last Updated: 06/28/2024             NaN
#
#        Country Name Country Code     2013 [YR2013]     2014 [YR2014]  \
# ...

# %%
#borramos columnas que no nos interesan
df_reservas.drop(columns = ["Series Name","Series Code","Country Code"],inplace=True)

# %%
#aplicamos funcion de limpieza
limpiar_nombres_columnas(df_reservas)
# Out:
#        Country Name              2013              2014              2015  \
# 0       Afghanistan  7288702710.90529  7528549879.63682  6976966153.82054
# 1           Albania  2773278107.16848   2665215805.2185  3138517990.16501
# 2           Algeria  201436604411.915  186350590140.833  150595236894.628
# 3    American Samoa                ..                ..                ..
# 4           Andorra                ..                ..                ..
# ..              ...               ...               ...               ...
# 266             NaN               NaN               NaN               NaN
# 267             NaN               NaN               NaN               NaN
# 268             NaN               NaN               NaN               NaN
# 269             NaN               NaN               NaN               NaN
# 270             NaN               NaN               NaN               NaN
#
#                  2016              2017              2018              2019  \
# ...

# %%
#borramos nans
df_reservas=df_reservas.dropna()

# %%
#corroboramos lista de paises
df_reservas["Country Name"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
# ...

# %%
#realizamos una lista con los valores de la columna country name que no eran paises 
no_paises2= ['Africa Eastern and Southern', 'Africa Western and Central',
       'Arab World', 'Caribbean small states',
       'Central Europe and the Baltics', 'Early-demographic dividend',
       'East Asia & Pacific',
       'East Asia & Pacific (excluding high income)',
       'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
       'Europe & Central Asia',
       'Europe & Central Asia (excluding high income)',
       'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
       'Fragile and conflict affected situations',
       'Heavily indebted poor countries (HIPC)', 'High income',
       'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
       'IDA total', 'Late-demographic dividend',
       'Latin America & Caribbean',
       'Latin America & Caribbean (excluding high income)',
       'Latin America & the Caribbean (IDA & IBRD countries)',
       'Least developed countries: UN classification',
       'Low & middle income', 'Low income', 'Lower middle income',
       'Middle East & North Africa',
       'Middle East & North Africa (excluding high income)',
       'Middle East & North Africa (IDA & IBRD countries)',
       'Middle income', 'North America', 'Not classified', 'OECD members',
       'Other small states', 'Pacific island small states',
       'Post-demographic dividend', 'Pre-demographic dividend',
       'Small states', 'South Asia', 'South Asia (IDA & IBRD)',
       'Sub-Saharan Africa', 'Sub-Saharan Africa (excluding high income)',
       'Sub-Saharan Africa (IDA & IBRD countries)', 'Upper middle income',
       'World']

# Creamos un nuevo DataFrame excluyendo los no países en no_paises2
df_reservas = df_reservas.loc[~df_reservas['Country Name'].isin(no_paises2)]

df_reservas.tail()
# Out:
#               Country Name              2013              2014  \
# 212  Virgin Islands (U.S.)                ..                ..
# 213     West Bank and Gaza      685224934.26      672378108.54
# 214            Yemen, Rep.  5344296754.57831  4357504076.77657
# 215                 Zambia  2683813403.45787  3078362296.84348
# 216               Zimbabwe   474968710.14602  363832802.383277
#
#                  2015              2016              2017              2018  \
# 212                ..                ..                ..                ..
# 213      580939642.18      312800333.67      446349334.35      537846124.64
# 214  1442757093.53636  877442199.453388  920558927.722887   2983208349.3994
# 215  2967626716.43206  2352719004.10271  2082083919.53427  1569229906.13102
# 216  434586085.852928  407193244.098736  292621249.111638  86951094.0294849
#
#                  2019              2020              2021              2022  \
# ...

# %%
#volvemos a corroborar cantidad de paises
df_reservas["Country Name"].nunique()
# Out:
# 217

# %%
#volvemos a corroborar lista de paises
df_reservas["Country Name"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
# ...

# %%
# array con listas de paises para ver coincidencias. Mapeo para tradudir al español
array7= ['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
       'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
       'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
       'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
       'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
       'Botswana', 'Brazil', 'British Virgin Islands',
       'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
       'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
       'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
       'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
       'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
       'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica',
       'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
       'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia',
       'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Polynesia',
       'Gabon', 'Gambia, The', 'Georgia', 'Germany', 'Ghana', 'Gibraltar',
       'Greece', 'Greenland', 'Grenada', 'Guam', 'Guatemala', 'Guinea',
       'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras',
       'Hong Kong SAR, China', 'Hungary', 'Iceland', 'India', 'Indonesia',
       'Iran, Islamic Rep.', 'Iraq', 'Ireland', 'Isle of Man', 'Israel',
       'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya',
       'Kiribati', "Korea, Dem. People's Rep.", 'Korea, Rep.', 'Kosovo',
       'Kuwait', 'Kyrgyz Republic', 'Lao PDR', 'Latvia', 'Lebanon',
       'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania',
       'Luxembourg', 'Macao SAR, China', 'Madagascar', 'Malawi',
       'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands',
       'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Fed. Sts.',
       'Moldova', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco',
       'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal',
       'Netherlands', 'New Caledonia', 'New Zealand', 'Nicaragua',
       'Niger', 'Nigeria', 'North Macedonia', 'Northern Mariana Islands',
       'Norway', 'Oman', 'Pakistan', 'Palau', 'Panama',
       'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland',
       'Portugal', 'Puerto Rico', 'Qatar', 'Romania',
       'Russian Federation', 'Rwanda', 'Samoa', 'San Marino',
       'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
       'Seychelles', 'Sierra Leone', 'Singapore',
       'Sint Maarten (Dutch part)', 'Slovak Republic', 'Slovenia',
       'Solomon Islands', 'Somalia', 'South Africa', 'South Sudan',
       'Spain', 'Sri Lanka', 'St. Kitts and Nevis', 'St. Lucia',
       'St. Martin (French part)', 'St. Vincent and the Grenadines',
       'Sudan', 'Suriname', 'Sweden', 'Switzerland',
       'Syrian Arab Republic', 'Tajikistan', 'Tanzania', 'Thailand',
       'Timor-Leste', 'Togo', 'Tonga', 'Trinidad and Tobago', 'Tunisia',
       'Turkiye', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu',
       'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom',
       'United States', 'Uruguay', 'Uzbekistan', 'Vanuatu',
       'Venezuela, RB', 'Viet Nam', 'Virgin Islands (U.S.)',
       'West Bank and Gaza', 'Yemen, Rep.', 'Zambia', 'Zimbabwe']

array8 =['España', 'Alemania', 'Reino Unido', 'Francia', 'Italia',
       'Portugal', 'Estados Unidos', 'Japón', 'China', 'Andorra',
       'Emiratos Árabes Unidos', 'Afganistán', 'Antigua y Barbuda',
       'Albania', 'Armenia', 'Angola', 'Argentina', 'Austria',
       'Australia', 'Azerbaiyán', 'Bosnia y Herzegovina', 'Barbados',
       'Bangladés', 'Bélgica', 'Burkina Faso', 'Bulgaria', 'Baréin',
       'Burundi', 'Benin', 'Brunéi', 'Bolivia', 'Brasil', 'Bahamas',
       'Bután', 'Botsuana', 'Bielorrusia', 'Belice', 'Canadá',
       'República Democrática del Congo', 'República Centroafricana',
       'República del Congo', 'Suiza', 'Costa de Marfil', 'Chile',
       'Camerún', 'Colombia', 'Costa Rica', 'Cuba', 'Cabo Verde',
       'Chipre', 'Chequia', 'Yibuti', 'Dinamarca', 'Dominica',
       'República Dominicana', 'Argelia', 'Ecuador', 'Estonia', 'Egipto',
       'Eritrea', 'Etiopía', 'Finlandia', 'Fiyi',
       'Estados Federados de Micronesia', 'Gabón', 'Granada', 'Georgia',
       'Ghana', 'Gambia', 'Guinea', 'Guinea Ecuatorial', 'Grecia',
       'Guatemala', 'Guinea-Bisáu', 'Guyana', 'Hong Kong', 'Honduras',
       'Croacia', 'Haití', 'Hungría', 'Indonesia', 'Irlanda', 'Israel',
       'India', 'Irak', 'Irán', 'Islandia', 'Jamaica', 'Jordania',
       'Kenia', 'Kirguistán', 'Camboya', 'Kiribati', 'Comoras',
       'San Cristóbal y Nieves', 'Corea del Norte', 'Corea del Sur',
       'Kuwait', 'Kazajistán', 'Laos', 'Líbano', 'Santa Lucía',
       'Liechtenstein', 'Sri Lanka', 'Liberia', 'Lesoto', 'Lituania',
       'Luxemburgo', 'Letonia', 'Libia', 'Marruecos', 'Moldavia',
       'Montenegro', 'Madagascar', 'Islas Marshall',
       'Macedonia del Norte', 'Malí', 'Myanmar', 'Mongolia', 'Mauritania',
       'Malta', 'Mauricio', 'Maldivas', 'Malaui', 'México', 'Malasia',
       'Mozambique', 'Namibia', 'Níger', 'Nigeria', 'Nicaragua',
       'Países Bajos', 'Noruega', 'Nepal', 'Nauru', 'Nueva Zelanda',
       'Omán', 'Panamá', 'Perú', 'Papúa Nueva Guinea', 'Filipinas',
       'Pakistán', 'Polonia', 'Palaos', 'Paraguay', 'Catar', 'Rumanía',
       'Serbia', 'Rusia', 'Ruanda', 'Arabia Saudita', 'Islas Salomón',
       'Seychelles', 'Sudán', 'Suecia', 'Singapur', 'Eslovenia',
       'Eslovaquia', 'Sierra Leona', 'Senegal', 'Surinam',
       'Sudán del Sur', 'Santo Tomé y Príncipe', 'El Salvador', 'Siria',
       'Eswatini', 'Chad', 'Togo', 'Tailandia', 'Tayikistán',
       'Timor Oriental', 'Turkmenistán', 'Túnez', 'Tonga', 'Türkiye',
       'Trinidad y Tobago', 'Tuvalu', 'Taiwan', 'Tanzania', 'Ucrania',
       'Uganda', 'Uruguay', 'Uzbekistán', 'San Vicente y las Granadinas',
       'Venezuela', 'Viet Nam', 'Vanuatu', 'Samoa', 'Yemen', 'Sudáfrica',
       'Zambia', 'Zimbabue']

mapeo_paises = {
    'Afghanistan': 'Afganistán',
    'Albania': 'Albania',
    'Algeria': 'Argelia',
    'American Samoa': 'Samoa Americana',
    'Andorra': 'Andorra',
    'Angola': 'Angola',
    'Antigua and Barbuda': 'Antigua y Barbuda',
    'Argentina': 'Argentina',
    'Armenia': 'Armenia',
    'Aruba': 'Aruba',
    'Australia': 'Australia',
    'Austria': 'Austria',
    'Azerbaijan': 'Azerbaiyán',
    'Bahamas, The': 'Bahamas',
    'Bahrain': 'Baréin',
    'Bangladesh': 'Bangladés',
    'Barbados': 'Barbados',
    'Belarus': 'Bielorrusia',
    'Belgium': 'Bélgica',
    'Belize': 'Belice',
    'Benin': 'Benin',
    'Bermuda': 'Bermudas',
    'Bhutan': 'Bután',
    'Bolivia': 'Bolivia',
    'Bosnia and Herzegovina': 'Bosnia y Herzegovina',
    'Botswana': 'Botsuana',
    'Brazil': 'Brasil',
    'British Virgin Islands': 'Islas Vírgenes Británicas',
    'Brunei Darussalam': 'Brunéi',
    'Bulgaria': 'Bulgaria',
    'Burkina Faso': 'Burkina Faso',
    'Burundi': 'Burundi',
    'Cabo Verde': 'Cabo Verde',
    'Cambodia': 'Camboya',
    'Cameroon': 'Camerún',
    'Canada': 'Canadá',
    'Cayman Islands': 'Islas Caimán',
    'Central African Republic': 'República Centroafricana',
    'Chad': 'Chad',
    'Channel Islands': 'Islas del Canal',
    'Chile': 'Chile',
    'China': 'China',
    'Colombia': 'Colombia',
    'Comoros': 'Comoras',
    'Congo, Dem. Rep.': 'República Democrática del Congo',
    'Congo, Rep.': 'República del Congo',
    'Costa Rica': 'Costa Rica',
    'Cote d\'Ivoire': 'Costa de Marfil',
    'Croatia': 'Croacia',
    'Cuba': 'Cuba',
    'Curacao': 'Curazao',
    'Cyprus': 'Chipre',
    'Czechia': 'Chequia',
    'Denmark': 'Dinamarca',
    'Djibouti': 'Yibuti',
    'Dominica': 'Dominica',
    'Dominican Republic': 'República Dominicana',
    'Ecuador': 'Ecuador',
    'Egypt, Arab Rep.': 'Egipto',
    'El Salvador': 'El Salvador',
    'Equatorial Guinea': 'Guinea Ecuatorial',
    'Eritrea': 'Eritrea',
    'Estonia': 'Estonia',
    'Eswatini': 'Eswatini',
    'Ethiopia': 'Etiopía',
    'Faroe Islands': 'Islas Faroe',
    'Fiji': 'Fiyi',
    'Finland': 'Finlandia',
    'France': 'Francia',
    'French Polynesia': 'Polinesia Francesa',
    'Gabon': 'Gabón',
    'Gambia, The': 'Gambia',
    'Georgia': 'Georgia',
    'Germany': 'Alemania',
    'Ghana': 'Ghana',
    'Gibraltar': 'Gibraltar',
    'Greece': 'Grecia',
    'Greenland': 'Groenlandia',
    'Grenada': 'Granada',
    'Guam': 'Guam',
    'Guatemala': 'Guatemala',
    'Guinea': 'Guinea',
    'Guinea-Bissau': 'Guinea-Bisáu',
    'Guyana': 'Guyana',
    'Haiti': 'Haití',
    'Honduras': 'Honduras',
    'Hong Kong SAR, China': 'Hong Kong',
    'Hungary': 'Hungría',
    'Iceland': 'Islandia',
    'India': 'India',
    'Indonesia': 'Indonesia',
    'Iran, Islamic Rep.': 'Irán',
    'Iraq': 'Irak',
    'Ireland': 'Irlanda',
    'Isle of Man': 'Isla de Man',
    'Israel': 'Israel',
    'Italy': 'Italia',
    'Jamaica': 'Jamaica',
    'Japan': 'Japón',
    'Jordan': 'Jordania',
    'Kazakhstan': 'Kazajistán',
    'Kenya': 'Kenia',
    'Kiribati': 'Kiribati',
    'Korea, Dem. People\'s Rep.': 'Corea del Norte',
    'Korea, Rep.': 'Corea del Sur',
    'Kosovo': 'Kosovo',
    'Kuwait': 'Kuwait',
    'Kyrgyz Republic': 'Kirguistán',
    'Lao PDR': 'Laos',
    'Latvia': 'Letonia',
    'Lebanon': 'Líbano',
    'Lesotho': 'Lesoto',
    'Liberia': 'Liberia',
    'Libya': 'Libia',
    'Liechtenstein': 'Liechtenstein',
    'Lithuania': 'Lituania',
    'Luxembourg': 'Luxemburgo',
    'Macao SAR, China': 'Macao',
    'Madagascar': 'Madagascar',
    'Malawi': 'Malawi',
    'Malaysia': 'Malasia',
    'Maldives': 'Maldivas',
    'Mali': 'Malí',
    'Malta': 'Malta',
    'Marshall Islands': 'Islas Marshall',
    'Mauritania': 'Mauritania',
    'Mauritius': 'Mauricio',
    'Mexico': 'México',
    'Micronesia, Fed. Sts.': 'Micronesia',
    'Moldova': 'Moldavia',
    'Monaco': 'Mónaco',
    'Mongolia': 'Mongolia',
    'Montenegro': 'Montenegro',
    'Morocco': 'Marruecos',
    'Mozambique': 'Mozambique',
    'Myanmar': 'Myanmar',
    'Namibia': 'Namibia',
    'Nauru': 'Nauru',
    'Nepal': 'Nepal',
    'Netherlands': 'Países Bajos',
    'New Caledonia': 'Nueva Caledonia',
    'New Zealand': 'Nueva Zelanda',
    'Nicaragua': 'Nicaragua',
    'Niger': 'Níger',
    'Nigeria': 'Nigeria',
    'North Macedonia': 'Macedonia del Norte',
    'Northern Mariana Islands': 'Islas Marianas del Norte',
    'Norway': 'Noruega',
    'Oman': 'Omán',
    'Pakistan': 'Pakistán',
    'Palau': 'Palaos',
    'Panama': 'Panamá',
    'Papua New Guinea': 'Papúa Nueva Guinea',
    'Paraguay': 'Paraguay',
    'Peru': 'Perú',
    'Philippines': 'Filipinas',
    'Poland': 'Polonia',
    'Portugal': 'Portugal',
    'Puerto Rico': 'Puerto Rico',
    'Qatar': 'Catar',
    'Romania': 'Rumanía',
    'Russian Federation': 'Rusia',
    'Rwanda': 'Ruanda',
    'Samoa': 'Samoa',
    'San Marino': 'San Marino',
    'Sao Tome and Principe': 'Santo Tomé y Príncipe',
    'Saudi Arabia': 'Arabia Saudita',
    'Senegal': 'Senegal',
    'Serbia': 'Serbia',
    'Seychelles': 'Seychelles',
    'Sierra Leone': 'Sierra Leona',
    'Singapore': 'Singapur',
    'Sint Maarten (Dutch part)': 'Sint Maarten',
    'Slovak Republic': 'Eslovaquia',
    'Slovenia': 'Eslovenia',
    'Solomon Islands': 'Islas Salomón',
    'Somalia': 'Somalia',
    'South Africa': 'Sudáfrica',
    'South Sudan': 'Sudán del Sur',
    'Spain': 'España',
    'Sri Lanka': 'Sri Lanka',
    'St. Kitts and Nevis': 'San Cristóbal y Nieves',
    'St. Lucia': 'Santa Lucía',
    'St. Martin (French part)': 'San Martín',
    'St. Vincent and the Grenadines': 'San Vicente y las Granadinas',
    'Sudan': 'Sudán',
    'Suriname': 'Surinam',
    'Sweden': 'Suecia',
    'Switzerland': 'Suiza',
    'Syrian Arab Republic': 'Siria',
    'Tajikistan': 'Tayikistán',
    'Tanzania': 'Tanzania',
    'Thailand': 'Tailandia',
    'Timor-Leste': 'Timor Oriental',
    'Togo': 'Togo',
    'Tonga': 'Tonga',
    'Trinidad and Tobago': 'Trinidad y Tobago',
    'Tunisia': 'Túnez',
    'Turkiye': 'Turquía',
    'Turkmenistan': 'Turkmenistán',
    'Turks and Caicos Islands': 'Islas Turcas y Caicos',
    'Tuvalu': 'Tuvalu',
    'Uganda': 'Uganda',
    'Ukraine': 'Ucrania',
    'United Arab Emirates': 'Emiratos Árabes Unidos',
    'United Kingdom': 'Reino Unido',
    'United States': 'Estados Unidos',
    'Uruguay': 'Uruguay',
    'Uzbekistan': 'Uzbekistán',
    'Vanuatu': 'Vanuatu',
    'Venezuela, RB': 'Venezuela',
    'Viet Nam': 'Vietnam',
    'Virgin Islands (U.S.)': 'Islas Vírgenes de los EE.UU.',
    'West Bank and Gaza': 'Cisjordania y Gaza',
    'Yemen, Rep.': 'Yemen',
    'Zambia': 'Zambia',
    'Zimbabwe': 'Zimbabue'
}

df_reservas['Country Name'] = df_reservas['Country Name'].map(mapeo_paises)

# %%
# convertimos los arrays en sets para luego buscar su interseccion y quedarnos con un df con esos paises coincidentes
array_1 = ['Afganistán', 'Albania', 'Argelia', 'Samoa Americana', 'Andorra', 'Angola', 'Antigua y Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaiyán', 'Bahamas', 'Baréin', 'Bangladés', 'Barbados', 'Bielorrusia', 'Bélgica', 'Belice', 'Benin', 'Bermudas', 'Bután', 'Bolivia', 'Bosnia y Herzegovina', 'Botsuana', 'Brasil', 'Islas Vírgenes Británicas', 'Brunéi', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Camboya', 'Camerún', 'Canadá', 'Islas Caimán', 'República Centroafricana', 'Chad', 'Islas del Canal', 'Chile', 'China', 'Colombia', 'Comoras', 'República Democrática del Congo', 'República del Congo', 'Costa Rica', 'Costa de Marfil', 'Croacia', 'Cuba', 'Curazao', 'Chipre', 'Chequia', 'Dinamarca', 'Yibuti', 'Dominica', 'República Dominicana', 'Ecuador', 'Egipto', 'El Salvador', 'Guinea Ecuatorial', 'Eritrea', 'Estonia', 'Eswatini', 'Etiopía', 'Islas Faroe', 'Fiyi', 'Finlandia', 'Francia', 'Polinesia Francesa', 'Gabón', 'Gambia', 'Georgia', 'Alemania', 'Ghana', 'Gibraltar', 'Grecia', 'Groenlandia', 'Granada', 'Guam', 'Guatemala', 'Guinea', 'Guinea-Bisáu', 'Guyana', 'Haití', 'Honduras', 'Hong Kong', 'Hungría', 'Islandia', 'India', 'Indonesia', 'Irán', 'Irak', 'Irlanda', 'Isla de Man', 'Israel', 'Italia', 'Jamaica', 'Japón', 'Jordania', 'Kazajistán', 'Kenia', 'Kiribati', 'Corea del Norte', 'Corea del Sur', 'Kosovo', 'Kuwait', 'Kirguistán', 'Laos', 'Letonia', 'Líbano', 'Lesoto', 'Liberia', 'Libia', 'Liechtenstein', 'Lituania', 'Luxemburgo', 'Macao', 'Madagascar', 'Malawi', 'Malasia', 'Maldivas', 'Malí', 'Malta', 'Islas Marshall', 'Mauritania', 'Mauricio', 'México', 'Micronesia', 'Moldavia', 'Mónaco', 'Mongolia', 'Montenegro', 'Marruecos', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Países Bajos', 'Nueva Caledonia', 'Nueva Zelanda', 'Nicaragua', 'Níger', 'Nigeria', 'Macedonia del Norte', 'Islas Marianas del Norte', 'Noruega', 'Omán', 'Pakistán', 'Palaos', 'Panamá', 'Papúa Nueva Guinea', 'Paraguay', 'Perú', 'Filipinas', 'Polonia', 'Portugal', 'Puerto Rico', 'Catar', 'Rumanía', 'Rusia', 'Ruanda', 'Samoa', 'San Marino', 'Santo Tomé y Príncipe', 'Arabia Saudita', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leona', 'Singapur', 'Sint Maarten', 'Eslovaquia', 'Eslovenia', 'Islas Salomón', 'Somalia', 'Sudáfrica', 'Sudán del Sur', 'España', 'Sri Lanka', 'San Cristóbal y Nieves', 'Santa Lucía', 'San Martín', 'San Vicente y las Granadinas', 'Sudán', 'Surinam', 'Suecia', 'Suiza', 'Siria', 'Tayikistán', 'Tanzania', 'Tailandia', 'Timor Oriental', 'Togo', 'Tonga', 'Trinidad y Tobago', 'Túnez', 'Turquía', 'Turkmenistán', 'Islas Turcas y Caicos', 'Tuvalu', 'Uganda', 'Ucrania', 'Emiratos Árabes Unidos', 'Reino Unido', 'Estados Unidos', 'Uruguay', 'Uzbekistán', 'Vanuatu', 'Venezuela', 'Vietnam', 'Islas Vírgenes de los EE.UU.', 'Cisjordania y Gaza', 'Yemen', 'Zambia', 'Zimbabue']

array_2 = ['España', 'Alemania', 'Reino Unido', 'Francia', 'Italia', 'Portugal', 'Estados Unidos', 'Japón', 'China', 'Andorra', 'Emiratos Árabes Unidos', 'Afganistán', 'Antigua y Barbuda', 'Albania', 'Armenia', 'Angola', 'Argentina', 'Austria', 'Australia', 'Azerbaiyán', 'Bosnia y Herzegovina', 'Barbados', 'Bangladés', 'Bélgica', 'Burkina Faso', 'Bulgaria', 'Baréin', 'Burundi', 'Benin', 'Brunéi', 'Bolivia', 'Brasil', 'Bahamas', 'Bután', 'Botsuana', 'Bielorrusia', 'Belice', 'Canadá', 'República Democrática del Congo', 'República Centroafricana', 'República del Congo', 'Suiza', 'Costa de Marfil', 'Chile', 'Camerún', 'Colombia', 'Costa Rica', 'Cuba', 'Cabo Verde', 'Chipre', 'Chequia', 'Yibuti', 'Dinamarca', 'Dominica', 'República Dominicana', 'Argelia', 'Ecuador', 'Estonia', 'Egipto', 'Eritrea', 'Etiopía', 'Finlandia', 'Fiyi', 'Estados Federados de Micronesia', 'Gabón', 'Granada', 'Georgia', 'Ghana', 'Gambia', 'Guinea', 'Guinea Ecuatorial', 'Grecia', 'Guatemala', 'Guinea-Bisáu', 'Guyana', 'Hong Kong', 'Honduras', 'Croacia', 'Haití', 'Hungría', 'Indonesia', 'Irlanda', 'Israel', 'India', 'Irak', 'Irán', 'Islandia', 'Jamaica', 'Jordania', 'Kenia', 'Kirguistán', 'Camboya', 'Kiribati', 'Comoras', 'San Cristóbal y Nieves', 'Corea del Norte', 'Corea del Sur', 'Kuwait', 'Kazajistán', 'Laos', 'Líbano', 'Santa Lucía', 'Liechtenstein', 'Sri Lanka', 'Liberia', 'Lesoto', 'Lituania', 'Luxemburgo', 'Letonia', 'Libia', 'Marruecos', 'Moldavia', 'Montenegro', 'Madagascar', 'Islas Marshall', 'Macedonia del Norte', 'Malí', 'Myanmar', 'Mongolia', 'Mauritania', 'Malta', 'Mauricio', 'Maldivas', 'Malaui', 'México', 'Malasia', 'Mozambique', 'Namibia', 'Níger', 'Nigeria', 'Nicaragua', 'Países Bajos', 'Noruega', 'Nepal', 'Nauru', 'Nueva Zelanda', 'Omán', 'Panamá', 'Perú', 'Papúa Nueva Guinea', 'Filipinas', 'Pakistán', 'Polonia', 'Palaos', 'Paraguay', 'Catar', 'Rumanía', 'Serbia', 'Rusia', 'Ruanda', 'Arabia Saudita', 'Islas Salomón', 'Seychelles', 'Sudán', 'Suecia', 'Singapur', 'Eslovenia', 'Eslovaquia', 'Sierra Leona', 'Senegal', 'Surinam', 'Sudán del Sur', 'Santo Tomé y Príncipe', 'El Salvador', 'Siria', 'Eswatini', 'Chad', 'Togo', 'Tailandia', 'Tayikistán', 'Timor Oriental', 'Turkmenistán', 'Túnez', 'Tonga', 'Türkiye', 'Trinidad y Tobago', 'Tuvalu', 'Taiwan', 'Tanzania', 'Ucrania', 'Uganda', 'Uruguay', 'Uzbekistán', 'San Vicente y las Granadinas', 'Venezuela', 'Viet Nam', 'Vanuatu', 'Samoa', 'Yemen', 'Sudáfrica', 'Zambia', 'Zimbabue']

set_esp = set(array_1)
set_eng = set(array_2)

intersection = set_esp.intersection(set_eng)

df_reservas =df_reservas[df_reservas['Country Name'].isin(intersection)]

# %%
df_reservas["Country Name"].nunique()
# Out:
# 187

# %%
import pandas as pd
import numpy as np

# Reemplazamos los valores '..' con NaN
df_reservas.replace('..', np.nan, inplace=True)

# %%
df_reservas.isnull().sum()
# Out:
# Country Name     0
# 2013            20
# 2014            20
# 2015            20
# 2016            20
# 2017            21
# 2018            23
# 2019            25
# 2020            28
# 2021            33
# 2022            39
# 2023            54
# dtype: int64

# %%
#borramos nans y verificamos cantidad de paises
df_reservas.dropna(inplace=True)
df_reservas["Country Name"].nunique()
# Out:
# 133

# %%
# modificamos la disposicion de las columnas para mejor visualizacion
df_reservas = pd.melt(df_reservas, id_vars=['Country Name'], var_name='Año', value_name='Reservas Internacionales')

df_reservas
# Out:
#            Country Name   Año Reservas Internacionales
# 0               Albania  2013         2773278107.16848
# 1               Argelia  2013         201436604411.915
# 2                Angola  2013         31500815461.6599
# 3     Antigua y Barbuda  2013         202580586.969295
# 4             Argentina  2013         30533919650.6264
# ...                 ...   ...                      ...
# 1458     Estados Unidos  2023         773426187289.128
# 1459            Uruguay  2023         16256769466.6151
# 1460         Uzbekistán  2023         34557511091.0994
# 1461            Vanuatu  2023         643768389.576285
# 1462           Zimbabue  2023         115529709.859095
#
# [1463 rows x 3 columns]

# %%
#corroboramos tipos de las columnas 
df_reservas.dtypes
# Out:
# Country Name                object
# Año                         object
# Reservas Internacionales    object
# dtype: object

# %%
#modificamos el tipo de la columna de año
df_reservas["Reservas Internacionales"]=df_reservas["Reservas Internacionales"].astype(float)

# %%
df_reservas.dtypes
# Out:
# Country Name                 object
# Año                          object
# Reservas Internacionales    float64
# dtype: object

# %%
df_reservas["Año"].value_counts()
# Out:
# Año
# 2013    133
# 2014    133
# 2015    133
# 2016    133
# 2017    133
# 2018    133
# 2019    133
# 2020    133
# 2021    133
# 2022    133
# 2023    133
# Name: count, dtype: int64

# %%
df_reservas.to_csv("df_reservas_limpio.csv",index=False)

# %%
df_reservas["Country Name"].nunique()
# Out:
# 133

# %%
df_reservas
# Out:
#            Country Name   Año  Reservas Internacionales
# 0               Albania  2013              2.773278e+09
# 1               Argelia  2013              2.014366e+11
# 2                Angola  2013              3.150082e+10
# 3     Antigua y Barbuda  2013              2.025806e+08
# 4             Argentina  2013              3.053392e+10
# ...                 ...   ...                       ...
# 1458     Estados Unidos  2023              7.734262e+11
# 1459            Uruguay  2023              1.625677e+10
# 1460         Uzbekistán  2023              3.455751e+10
# 1461            Vanuatu  2023              6.437684e+08
# 1462           Zimbabue  2023              1.155297e+08
#
# [1463 rows x 3 columns]

# %%
df_reservas.sort_values(by=["Country Name", "Año"], inplace=True)
df_reservas
# Out:
#      Country Name   Año  Reservas Internacionales
# 0         Albania  2013              2.773278e+09
# 133       Albania  2014              2.665216e+09
# 266       Albania  2015              3.138518e+09
# 399       Albania  2016              3.108607e+09
# 532       Albania  2017              3.588584e+09
# ...           ...   ...                       ...
# 930      Zimbabue  2019              1.512405e+08
# 1063     Zimbabue  2020              3.340502e+07
# 1196     Zimbabue  2021              8.387802e+08
# 1329     Zimbabue  2022              5.986216e+08
# 1462     Zimbabue  2023              1.155297e+08
#
# [1463 rows x 3 columns]

# %%
df_reservas.dtypes
# Out:
# Country Name                 object
# Año                          object
# Reservas Internacionales    float64
# dtype: object

# %% [markdown]
# ## DEFICIT PUBLICO

# %%
df_deficit = pd.read_csv("/Users/rodri/Desktop/Proyecto final/Datos/Indicadores economicos/df_deficit.csv")
df_deficit
# Out:
#             Pais   Año Deficit Publico (M) Deficit Publico (%PIB)
# 0     Afganistán  2013               -96.0                  -0,63
# 1     Afganistán  2014              -267.0                  -1,72
# 2     Afganistán  2015              -249.0                  -1,38
# 3     Afganistán  2016                21.0                   0,13
# 4     Afganistán  2017              -113.0                  -0,67
# ...          ...   ...                 ...                    ...
# 1887    Zimbabue  2017              -2.014                 -10,64
# 1888    Zimbabue  2018              -1.698                  -5,43
# 1889    Zimbabue  2019                -205                  -1,00
# 1890    Zimbabue  2020                 177                   0,75
# 1891    Zimbabue  2021                -658                  -2,16
#
# [1892 rows x 4 columns]

# %%
#cambiamos nombre de columna
df_deficit.rename(columns={"Pais":"Country Name"},inplace=True)

# %%
#corroboramos el tipo de datos
df_deficit.dtypes
# Out:
# Country Name              object
# Año                        int64
# Deficit Publico (M)       object
# Deficit Publico (%PIB)    object
# dtype: object

# %%
#cambiamos el tipo de año 
df_deficit["Año"]=df_deficit["Año"].astype(object)

# %%
#cambiamos el tipo de deficit publico
df_deficit['Deficit Publico (M)'] = df_deficit['Deficit Publico (M)'].str.replace('.', '', regex=False).astype(float)

# %%
#cambiamos el tipo de deficit publico %pib
df_deficit['Deficit Publico (%PIB)'] = df_deficit['Deficit Publico (%PIB)'].str.replace(',', '.').astype(float)

# %%
df_deficit.dtypes
# Out:
# Country Name               object
# Año                        object
# Deficit Publico (M)       float64
# Deficit Publico (%PIB)    float64
# dtype: object

# %%
df_deficit.to_csv("df_deficit_limpio.csv",index=False)

# %%
df_deficit["Country Name"].nunique()
# Out:
# 192

# %%
df_deficit["Año"].value_counts()
# Out:
# Año
# 2017    192
# 2013    191
# 2014    191
# 2015    191
# 2016    191
# 2018    190
# 2019    190
# 2020    190
# 2021    186
# 2022    149
# 2023     29
# 2009      2
# Name: count, dtype: int64

# %%
df_deficit
# Out:
#      Country Name   Año  Deficit Publico (M)  Deficit Publico (%PIB)
# 0      Afganistán  2013               -960.0                   -0.63
# 1      Afganistán  2014              -2670.0                   -1.72
# 2      Afganistán  2015              -2490.0                   -1.38
# 3      Afganistán  2016                210.0                    0.13
# 4      Afganistán  2017              -1130.0                   -0.67
# ...           ...   ...                  ...                     ...
# 1887     Zimbabue  2017              -2014.0                  -10.64
# 1888     Zimbabue  2018              -1698.0                   -5.43
# 1889     Zimbabue  2019               -205.0                   -1.00
# 1890     Zimbabue  2020                177.0                    0.75
# 1891     Zimbabue  2021               -658.0                   -2.16
#
# [1892 rows x 4 columns]

# %%
df_deficit.dtypes
# Out:
# Country Name               object
# Año                        object
# Deficit Publico (M)       float64
# Deficit Publico (%PIB)    float64
# dtype: object

# %% [markdown]
# ## TIPO DE CAMBIO

# %%
df_tipo_cambio=pd.read_csv("/Users/rodri/Desktop/Proyecto final/Datos/Indicadores economicos/tipo_cambio_nominal.csv",sep=";")

# %%
limpiar_nombres_columnas(df_tipo_cambio)
# Out:
#               Country Name              2013              2014  \
# 0              Afghanistan           55.3775           57.2475
# 1                  Albania  105.669166666667            105.48
# 2                  Algeria           79.3684  80.5790166666667
# 3           American Samoa                 1                 1
# 4                  Andorra            0.7529            0.7527
# ..                     ...               ...               ...
# 207          Venezuela, RB  6.04796184166667            6.2842
# 208               Viet Nam  20933.4166666667             21148
# 209  Virgin Islands (U.S.)                 1                 1
# 210            Yemen, Rep.            214.89            214.89
# 211                 Zambia  5.39648333333333  6.15416666666667
#
#                  2015              2016              2017              2018  \
# 0    61.1434615416667  67.8660857692308  68.0269040822312   72.083247177304
# ...

# %%
df_tipo_cambio["Country Name"].nunique()
# Out:
# 212

# %%
df_tipo_cambio.replace('..', np.nan, inplace=True)
df_tipo_cambio.dropna(inplace=True)

# %%
df_tipo_cambio["Country Name"].nunique()
# Out:
# 187

# %%
df_tipo_cambio = pd.melt(df_tipo_cambio, id_vars=['Country Name'], var_name='Año', value_name='Tipo de cambio Nominal')

df_tipo_cambio
# Out:
#                Country Name   Año Tipo de cambio Nominal
# 0                   Albania  2013       105.669166666667
# 1                   Algeria  2013                79.3684
# 2            American Samoa  2013                      1
# 3                   Andorra  2013                 0.7529
# 4                    Angola  2013       96.5182794791526
# ...                     ...   ...                    ...
# 2052             Uzbekistan  2023       11734.8334198669
# 2053                Vanuatu  2023               119.1125
# 2054               Viet Nam  2023       23787.3191666667
# 2055  Virgin Islands (U.S.)  2023                      1
# 2056                 Zambia  2023        20.212017866195
#
# [2057 rows x 3 columns]

# %%
df_tipo_cambio.isnull().sum()
# Out:
# Country Name              0
# Año                       0
# Tipo de cambio Nominal    0
# dtype: int64

# %%
df_tipo_cambio.duplicated().sum()
# Out:
# 0

# %%
df_tipo_cambio.to_csv("df_tipo_cambio.csv",index=False)

# %%
df_tipo_cambio["Country Name"].nunique()
# Out:
# 187

# %%
df_tipo_cambio
# Out:
#                Country Name   Año Tipo de cambio Nominal
# 0                   Albania  2013       105.669166666667
# 1                   Algeria  2013                79.3684
# 2            American Samoa  2013                      1
# 3                   Andorra  2013                 0.7529
# 4                    Angola  2013       96.5182794791526
# ...                     ...   ...                    ...
# 2052             Uzbekistan  2023       11734.8334198669
# 2053                Vanuatu  2023               119.1125
# 2054               Viet Nam  2023       23787.3191666667
# 2055  Virgin Islands (U.S.)  2023                      1
# 2056                 Zambia  2023        20.212017866195
#
# [2057 rows x 3 columns]

# %%
df_tipo_cambio
# Out:
#                Country Name   Año Tipo de cambio Nominal
# 0                   Albania  2013       105.669166666667
# 1                   Algeria  2013                79.3684
# 2            American Samoa  2013                      1
# 3                   Andorra  2013                 0.7529
# 4                    Angola  2013       96.5182794791526
# ...                     ...   ...                    ...
# 2052             Uzbekistan  2023       11734.8334198669
# 2053                Vanuatu  2023               119.1125
# 2054               Viet Nam  2023       23787.3191666667
# 2055  Virgin Islands (U.S.)  2023                      1
# 2056                 Zambia  2023        20.212017866195
#
# [2057 rows x 3 columns]

# %%
df_tipo_cambio.sort_values(by=["Country Name", "Año"], inplace=True)

# %%
df_tipo_cambio
# Out:
#      Country Name   Año Tipo de cambio Nominal
# 0         Albania  2013       105.669166666667
# 187       Albania  2014                 105.48
# 374       Albania  2015       125.961666666667
# 561       Albania  2016               124.1425
# 748       Albania  2017                  119.1
# ...           ...   ...                    ...
# 1308       Zambia  2019                  12.89
# 1495       Zambia  2020       18.3440926453379
# 1682       Zambia  2021       20.0184865859688
# 1869       Zambia  2022       16.9375943252989
# 2056       Zambia  2023        20.212017866195
#
# [2057 rows x 3 columns]

# %%
df_tipo_cambio["Country Name"].unique()
# Out:
# array(['Albania', 'Algeria', 'American Samoa', 'Andorra', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Corea del Sur', 'Costa Rica',
#        "Cote d'Ivoire", 'Curacao', 'Cyprus', 'Czechia', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Faroe Islands', 'Fiji', 'Finland',
#        'France', 'French Polynesia', 'Gabon', 'Gambia', 'Georgia',
# ...

# %%
mapeo_paises = {
    "Albania": "Albania",
    "Algeria": "Argelia",
    "American Samoa": "Samoa Americana",
    "Andorra": "Andorra",
    "Angola": "Angola",
    "Antigua and Barbuda": "Antigua y Barbuda",
    "Argentina": "Argentina",
    "Armenia": "Armenia",
    "Aruba": "Aruba",
    "Australia": "Australia",
    "Austria": "Austria",
    "Azerbaijan": "Azerbaiyán",
    "Bahamas": "Bahamas",
    "Bahrain": "Baréin",
    "Bangladesh": "Bangladés",
    "Barbados": "Barbados",
    "Belarus": "Bielorrusia",
    "Belgium": "Bélgica",
    "Belize": "Belice",
    "Benin": "Benín",
    "Bermuda": "Bermudas",
    "Bhutan": "Bután",
    "Bolivia": "Bolivia",
    "Bosnia and Herzegovina": "Bosnia y Herzegovina",
    "Botswana": "Botsuana",
    "Brazil": "Brasil",
    "Brunei Darussalam": "Brunéi",
    "Bulgaria": "Bulgaria",
    "Burkina Faso": "Burkina Faso",
    "Burundi": "Burundi",
    "Cabo Verde": "Cabo Verde",
    "Cambodia": "Camboya",
    "Cameroon": "Camerún",
    "Canada": "Canadá",
    "Central African Republic": "República Centroafricana",
    "Chad": "Chad",
    "Chile": "Chile",
    "China": "China",
    "Colombia": "Colombia",
    "Comoros": "Comoras",
    "Republica del Congo": "República del Congo",
    "Costa Rica": "Costa Rica",
    "Cote d'Ivoire": "Costa de Marfil",
    "Curacao": "Curazao",
    "Cyprus": "Chipre",
    "Czechia": "Chequia",
    "Denmark": "Dinamarca",
    "Djibouti": "Yibuti",
    "Dominica": "Dominica",
    "Dominican Republic": "República Dominicana",
    "Ecuador": "Ecuador",
    "Egypt": "Egipto",
    "El Salvador": "El Salvador",
    "Equatorial Guinea": "Guinea Ecuatorial",
    "Eritrea": "Eritrea",
    "Estonia": "Estonia",
    "Eswatini": "Eswatini",
    "Ethiopia": "Etiopía",
    "Faroe Islands": "Islas Feroe",
    "Fiji": "Fiyi",
    "Finland": "Finlandia",
    "France": "Francia",
    "French Polynesia": "Polinesia Francesa",
    "Gabon": "Gabón",
    "Gambia": "Gambia",
    "Georgia": "Georgia",
    "Germany": "Alemania",
    "Ghana": "Ghana",
    "Gibraltar": "Gibraltar",
    "Greece": "Grecia",
    "Greenland": "Groenlandia",
    "Grenada": "Granada",
    "Guam": "Guam",
    "Guatemala": "Guatemala",
    "Guinea-Bissau": "Guinea-Bisáu",
    "Guyana": "Guyana",
    "Haiti": "Haití",
    "Honduras": "Honduras",
    "Hong Kong": "Hong Kong",
    "Hungary": "Hungría",
    "Iceland": "Islandia",
    "India": "India",
    "Indonesia": "Indonesia",
    "Iran": "Irán",
    "Iraq": "Irak",
    "Ireland": "Irlanda",
    "Isle of Man": "Isla de Man",
    "Israel": "Israel",
    "Italy": "Italia",
    "Jamaica": "Jamaica",
    "Japan": "Japón",
    "Jordan": "Jordania",
    "Kazakhstan": "Kazajistán",
    "Kenya": "Kenia",
    "Kiribati": "Kiribati",
    "Corea del Sur": "Corea del Sur",
    "Kosovo": "Kosovo",
    "Kuwait": "Kuwait",
    "Kyrgyz Republic": "Kirguistán",
    "Lao PDR": "Laos",
    "Latvia": "Letonia",
    "Lesotho": "Lesoto",
    "Libya": "Libia",
    "Liechtenstein": "Liechtenstein",
    "Lithuania": "Lituania",
    "Luxembourg": "Luxemburgo",
    "Macao SAR": "Macao",
    "Madagascar": "Madagascar",
    "Malaysia": "Malasia",
    "Maldives": "Maldivas",
    "Mali": "Malí",
    "Malta": "Malta",
    "Marshall Islands": "Islas Marshall",
    "Mauritius": "Mauricio",
    "Mexico": "México",
    "Micronesia": "Micronesia",
    "Moldova": "Moldavia",
    "Monaco": "Mónaco",
    "Mongolia": "Mongolia",
    "Montenegro": "Montenegro",
    "Morocco": "Marruecos",
    "Mozambique": "Mozambique",
    "Namibia": "Namibia",
    "Nauru": "Nauru",
    "Nepal": "Nepal",
    "Netherlands": "Países Bajos",
    "New Caledonia": "Nueva Caledonia",
    "New Zealand": "Nueva Zelanda",
    "Nicaragua": "Nicaragua",
    "Niger": "Níger",
    "North Macedonia": "Macedonia del Norte",
    "Northern Mariana Islands": "Islas Marianas del Norte",
    "Norway": "Noruega",
    "Oman": "Omán",
    "Pakistan": "Pakistán",
    "Palau": "Palaos",
    "Panama": "Panamá",
    "Paraguay": "Paraguay",
    "Peru": "Perú",
    "Philippines": "Filipinas",
    "Poland": "Polonia",
    "Portugal": "Portugal",
    "Puerto Rico": "Puerto Rico",
    "Qatar": "Catar",
    "Romania": "Rumanía",
    "Russian Federation": "Rusia",
    "Rwanda": "Ruanda",
    "Samoa": "Samoa",
    "San Marino": "San Marino",
    "Saudi Arabia": "Arabia Saudita",
    "Senegal": "Senegal",
    "Serbia": "Serbia",
    "Sierra Leone": "Sierra Leona",
    "Singapore": "Singapur",
    "Sint Maarten (Dutch part)": "Sint Maarten",
    "Slovak Republic": "Eslovaquia",
    "Slovenia": "Eslovenia",
    "Solomon Islands": "Islas Salomón",
    "South Africa": "Sudáfrica",
    "Spain": "España",
    "St. Kitts and Nevis": "San Cristóbal y Nieves",
    "St. Lucia": "Santa Lucía",
    "St. Vincent and the Grenadines": "San Vicente y las Granadinas",
    "Suriname": "Surinam",
    "Sweden": "Suecia",
    "Switzerland": "Suiza",
    "Tajikistan": "Tayikistán",
    "Thailand": "Tailandia",
    "Timor-Leste": "Timor Oriental",
    "Togo": "Togo",
    "Tonga": "Tonga",
    "Trinidad and Tobago": "Trinidad y Tobago",
    "Tunisia": "Túnez",
    "Turkiye": "Türkiye",
    "Turks and Caicos Islands": "Islas Turcas y Caicos",
    "Tuvalu": "Tuvalu",
    "Uganda": "Uganda",
    "Ukraine": "Ucrania",
    "United Arab Emirates": "Emiratos Árabes Unidos",
    "United Kingdom": "Reino Unido",
    "United States": "Estados Unidos",
    "Uruguay": "Uruguay",
    "Uzbekistan": "Uzbekistán",
    "Vanuatu": "Vanuatu",
    "Viet Nam": "Vietnam",
    "Virgin Islands (U.S.)": "Islas Vírgenes (EE.UU.)",
    "Zambia": "Zambia"
}

df_tipo_cambio['Country Name'] = df_tipo_cambio['Country Name'].replace(mapeo_paises)

# %%
df_tipo_cambio.to_csv("df_tipo_cambio_limpio.csv",index=False)

# %%
df_tipo_cambio
# Out:
#      Country Name   Año Tipo de cambio Nominal
# 0         Albania  2013       105.669166666667
# 187       Albania  2014                 105.48
# 374       Albania  2015       125.961666666667
# 561       Albania  2016               124.1425
# 748       Albania  2017                  119.1
# ...           ...   ...                    ...
# 1308       Zambia  2019                  12.89
# 1495       Zambia  2020       18.3440926453379
# 1682       Zambia  2021       20.0184865859688
# 1869       Zambia  2022       16.9375943252989
# 2056       Zambia  2023        20.212017866195
#
# [2057 rows x 3 columns]

# %%
df_tipo_cambio.dtypes
# Out:
# Country Name              object
# Año                       object
# Tipo de cambio Nominal    object
# dtype: object

# %%
df_tipo_cambio["Tipo de cambio Nominal"]=df_tipo_cambio["Tipo de cambio Nominal"].astype(float)

# %%
df_tipo_cambio.dtypes
# Out:
# Country Name               object
# Año                        object
# Tipo de cambio Nominal    float64
# dtype: object

# %% [markdown]
# ## SALDO CUENTA CORRIENTE

# %%
df_cuenta_corriente = pd.read_csv("/Users/rodri/Desktop/Proyecto final/Datos/Indicadores economicos/Saldo Cuenta Corriente 9.32.18.csv",sep=";")
df_cuenta_corriente
# Out:
#     Country Name          2013          2014          2015          2016  \
# 0          Aruba -3.222465e+08 -1.300139e+08  1.183427e+08  1.411790e+08
# 1     Afganistán -5.095041e+09 -3.232893e+09 -4.192816e+09 -2.708463e+09
# 2         Angola  8.145070e+09 -3.747518e+09 -1.027284e+10 -3.085195e+09
# 3        Albania -1.184891e+09 -1.425386e+09 -9.798251e+08 -9.003630e+08
# 4      Argentina -1.312437e+10 -9.179026e+09 -1.762199e+10 -1.510479e+10
# ..           ...           ...           ...           ...           ...
# 176        Samoa -4.472993e+07 -4.646125e+07 -1.270970e+07 -3.843253e+07
# 177       Kosovo -2.411646e+08 -5.016112e+08 -5.473879e+08 -5.302320e+08
# 178    Sudáfrica -2.140079e+10 -1.834494e+10 -1.494419e+10 -8.521995e+09
# 179       Zambia -1.614821e+08 -3.873279e+08 -7.676518e+08 -9.539616e+08
# 180     Zimbabwe -2.648761e+09 -2.333838e+09 -1.596669e+09 -6.974505e+08
#
#              2017          2018          2019          2020          2021  \
# ...

# %%
df_cuenta_corriente["2023"]=df_cuenta_corriente["2022"]
df_cuenta_corriente
# Out:
#     Country Name          2013          2014          2015          2016  \
# 0          Aruba -3.222465e+08 -1.300139e+08  1.183427e+08  1.411790e+08
# 1     Afganistán -5.095041e+09 -3.232893e+09 -4.192816e+09 -2.708463e+09
# 2         Angola  8.145070e+09 -3.747518e+09 -1.027284e+10 -3.085195e+09
# 3        Albania -1.184891e+09 -1.425386e+09 -9.798251e+08 -9.003630e+08
# 4      Argentina -1.312437e+10 -9.179026e+09 -1.762199e+10 -1.510479e+10
# ..           ...           ...           ...           ...           ...
# 176        Samoa -4.472993e+07 -4.646125e+07 -1.270970e+07 -3.843253e+07
# 177       Kosovo -2.411646e+08 -5.016112e+08 -5.473879e+08 -5.302320e+08
# 178    Sudáfrica -2.140079e+10 -1.834494e+10 -1.494419e+10 -8.521995e+09
# 179       Zambia -1.614821e+08 -3.873279e+08 -7.676518e+08 -9.539616e+08
# 180     Zimbabwe -2.648761e+09 -2.333838e+09 -1.596669e+09 -6.974505e+08
#
#              2017          2018          2019          2020          2021  \
# ...

# %%
df_cuenta_corriente["Country Name"].nunique()
# Out:
# 181

# %%
df_cuenta_corriente.drop(columns=["Unnamed: 12"],inplace=True)
df_cuenta_corriente.dropna(inplace=True)
df_cuenta_corriente["Country Name"].nunique()
# Out:
# 165

# %%
df_cuenta_corriente = pd.melt(df_cuenta_corriente, id_vars=['Country Name'], var_name='Año', value_name='Saldo Cuenta Corriente')

df_cuenta_corriente
# Out:
#      Country Name   Año  Saldo Cuenta Corriente
# 0           Aruba  2013           -3.222465e+08
# 1          Angola  2013            8.145070e+09
# 2         Albania  2013           -1.184891e+09
# 3       Argentina  2013           -1.312437e+10
# 4         Armenia  2013           -8.136738e+08
# ...           ...   ...                     ...
# 1810      Vanuatu  2023           -1.274319e+08
# 1811        Samoa  2023           -8.667798e+07
# 1812       Kosovo  2023           -9.832832e+08
# 1813    Sudáfrica  2023           -1.697574e+09
# 1814       Zambia  2023            1.093014e+09
#
# [1815 rows x 3 columns]

# %%
df_cuenta_corriente.to_csv("df_cuenta_corriente_limpio.csv",index=False)

# %%
df_cuenta_corriente["Country Name"].nunique()
# Out:
# 165

# %%
df_cuenta_corriente
# Out:
#      Country Name   Año  Saldo Cuenta Corriente
# 0           Aruba  2013           -3.222465e+08
# 1          Angola  2013            8.145070e+09
# 2         Albania  2013           -1.184891e+09
# 3       Argentina  2013           -1.312437e+10
# 4         Armenia  2013           -8.136738e+08
# ...           ...   ...                     ...
# 1810      Vanuatu  2023           -1.274319e+08
# 1811        Samoa  2023           -8.667798e+07
# 1812       Kosovo  2023           -9.832832e+08
# 1813    Sudáfrica  2023           -1.697574e+09
# 1814       Zambia  2023            1.093014e+09
#
# [1815 rows x 3 columns]

# %%
df_cuenta_corriente.sort_values(by=["Country Name", "Año"], inplace=True)

# %%
df_cuenta_corriente
# Out:
#      Country Name   Año  Saldo Cuenta Corriente
# 2         Albania  2013           -1.184891e+09
# 167       Albania  2014           -1.425386e+09
# 332       Albania  2015           -9.798251e+08
# 497       Albania  2016           -9.003630e+08
# 662       Albania  2017           -9.822379e+08
# ...           ...   ...                     ...
# 1154       Zambia  2019            1.407123e+08
# 1319       Zambia  2020            2.138616e+09
# 1484       Zambia  2021            2.629551e+09
# 1649       Zambia  2022            1.093014e+09
# 1814       Zambia  2023            1.093014e+09
#
# [1815 rows x 3 columns]

# %%
df_cuenta_corriente.dtypes
# Out:
# Country Name               object
# Año                        object
# Saldo Cuenta Corriente    float64
# dtype: object

# %%
merged_df1 = df_pib.merge(df_inflacion, on=["Country Name", "Año"], how="inner")\

merged_df1
# Out:
#      Country Name   Año  Crecimiento_GDP(%)  Inflacion Anual(%)
# 0         Albania  2013            1.002018            1.937621
# 1         Albania  2014            1.774449            1.625865
# 2         Albania  2015            2.218726            1.896174
# 3         Albania  2016            3.314981            1.275432
# 4         Albania  2017            3.802599            1.986661
# ...           ...   ...                 ...                 ...
# 1568       Zambia  2019            1.441306            9.150316
# 1569       Zambia  2020           -2.785055           15.733060
# 1570       Zambia  2021            6.234922           22.020768
# 1571       Zambia  2022            5.249622           10.993204
# 1572       Zambia  2023            5.832474           10.884532
#
# [1573 rows x 4 columns]

# %%
merged_df2= merged_df1.merge(df_cuenta_corriente, on=["Country Name", "Año"], how="inner")\

merged_df2
# Out:
#      Country Name   Año  Crecimiento_GDP(%)  Inflacion Anual(%)  \
# 0         Albania  2013            1.002018            1.937621
# 1         Albania  2014            1.774449            1.625865
# 2         Albania  2015            2.218726            1.896174
# 3         Albania  2016            3.314981            1.275432
# 4         Albania  2017            3.802599            1.986661
# ...           ...   ...                 ...                 ...
# 1392       Zambia  2019            1.441306            9.150316
# 1393       Zambia  2020           -2.785055           15.733060
# 1394       Zambia  2021            6.234922           22.020768
# 1395       Zambia  2022            5.249622           10.993204
# 1396       Zambia  2023            5.832474           10.884532
#
#       Saldo Cuenta Corriente
# 0              -1.184891e+09
# 1              -1.425386e+09
# 2              -9.798251e+08
# 3              -9.003630e+08
# 4              -9.822379e+08
# ...

# %%
merged_df3= merged_df2.merge(df_reservas, on=["Country Name", "Año"], how="inner")\

merged_df3
# Out:
#      Country Name   Año  Crecimiento_GDP(%)  Inflacion Anual(%)  \
# 0         Albania  2013            1.002018            1.937621
# 1         Albania  2014            1.774449            1.625865
# 2         Albania  2015            2.218726            1.896174
# 3         Albania  2016            3.314981            1.275432
# 4         Albania  2017            3.802599            1.986661
# ...           ...   ...                 ...                 ...
# 1095      Vanuatu  2019            3.241188            2.762520
# 1096      Vanuatu  2020           -4.992491            5.329351
# 1097      Vanuatu  2021           -1.552295            2.343284
# 1098      Vanuatu  2022            1.916057            6.679306
# 1099      Vanuatu  2023            2.212942           14.400000
#
#       Saldo Cuenta Corriente  Reservas Internacionales
# 0              -1.184891e+09              2.773278e+09
# 1              -1.425386e+09              2.665216e+09
# ...

# %%
merged_df3["Country Name"].nunique()
# Out:
# 100

# %%
merged_df4= merged_df3.merge(df_tipo_cambio, on=["Country Name", "Año"], how="inner")

merged_df4
# Out:
#      Country Name   Año  Crecimiento_GDP(%)  Inflacion Anual(%)  \
# 0         Albania  2013            1.002018            1.937621
# 1         Albania  2014            1.774449            1.625865
# 2         Albania  2015            2.218726            1.896174
# 3         Albania  2016            3.314981            1.275432
# 4         Albania  2017            3.802599            1.986661
# ...           ...   ...                 ...                 ...
# 1084      Vanuatu  2019            3.241188            2.762520
# 1085      Vanuatu  2020           -4.992491            5.329351
# 1086      Vanuatu  2021           -1.552295            2.343284
# 1087      Vanuatu  2022            1.916057            6.679306
# 1088      Vanuatu  2023            2.212942           14.400000
#
#       Saldo Cuenta Corriente  Reservas Internacionales  Tipo de cambio Nominal
# 0              -1.184891e+09              2.773278e+09              105.669167
# ...

# %%
df_deficit.columns
# Out:
# Index(['Country Name', 'Año', 'Deficit Publico (M)', 'Deficit Publico (%PIB)'], dtype='object')

# %%
merged_df4.columns
# Out:
# Index(['Country Name', 'Año', 'Crecimiento_GDP(%)', 'Inflacion Anual(%)',
#        'Saldo Cuenta Corriente', 'Reservas Internacionales',
#        'Tipo de cambio Nominal'],
#       dtype='object')

# %%
df_deficit= df_deficit.sort_values(by=["Country Name", "Año"])

# %%
df_deficit
# Out:
#      Country Name   Año  Deficit Publico (M)  Deficit Publico (%PIB)
# 0      Afganistán  2013               -960.0                   -0.63
# 1      Afganistán  2014              -2670.0                   -1.72
# 2      Afganistán  2015              -2490.0                   -1.38
# 3      Afganistán  2016                210.0                    0.13
# 4      Afganistán  2017              -1130.0                   -0.67
# ...           ...   ...                  ...                     ...
# 1887     Zimbabue  2017              -2014.0                  -10.64
# 1888     Zimbabue  2018              -1698.0                   -5.43
# 1889     Zimbabue  2019               -205.0                   -1.00
# 1890     Zimbabue  2020                177.0                    0.75
# 1891     Zimbabue  2021               -658.0                   -2.16
#
# [1892 rows x 4 columns]

# %%
df_deficit["Año"]=df_deficit["Año"].astype(str)

# %%
df_5 = pd.merge(merged_df4, df_deficit, on=["Country Name", "Año"],)
df_5
# Out:
#      Country Name   Año  Crecimiento_GDP(%)  Inflacion Anual(%)  \
# 0         Albania  2013            1.002018            1.937621
# 1         Albania  2014            1.774449            1.625865
# 2         Albania  2015            2.218726            1.896174
# 3         Albania  2016            3.314981            1.275432
# 4         Albania  2017            3.802599            1.986661
# ...           ...   ...                 ...                 ...
# 1002      Vanuatu  2016            4.688756            0.842069
# 1003      Vanuatu  2017            6.317305            3.084526
# 1004      Vanuatu  2018            2.900230            2.330964
# 1005      Vanuatu  2019            3.241188            2.762520
# 1006      Vanuatu  2020           -4.992491            5.329351
#
#       Saldo Cuenta Corriente  Reservas Internacionales  \
# 0              -1.184891e+09              2.773278e+09
# 1              -1.425386e+09              2.665216e+09
# ...

# %%
df_balanza["Año"]=df_balanza["Año"].astype(str)

# %%
df_6 = pd.merge(df_5, df_balanza, on=["Country Name", "Año"],)
df_6
# Out:
#      Country Name   Año  Crecimiento_GDP(%)  Inflacion Anual(%)  \
# 0         Albania  2013            1.002018            1.937621
# 1         Albania  2014            1.774449            1.625865
# 2         Albania  2015            2.218726            1.896174
# 3         Albania  2016            3.314981            1.275432
# 4         Albania  2017            3.802599            1.986661
# ...           ...   ...                 ...                 ...
# 1002      Vanuatu  2016            4.688756            0.842069
# 1003      Vanuatu  2017            6.317305            3.084526
# 1004      Vanuatu  2018            2.900230            2.330964
# 1005      Vanuatu  2019            3.241188            2.762520
# 1006      Vanuatu  2020           -4.992491            5.329351
#
#       Saldo Cuenta Corriente  Reservas Internacionales  \
# 0              -1.184891e+09              2.773278e+09
# 1              -1.425386e+09              2.665216e+09
# ...

# %%
df_6["Country Name"].nunique()
# Out:
# 99

# %%
df_ied = pd.read_csv("/Users/rodri/Desktop/Proyecto final/Datos/df_ied_limpio.csv")
df_ied
# Out:
#                 Country Name   Año           IED
# 0                      Aruba  2013  2.720881e+08
# 1                 Afganistán  2013  4.831135e+07
# 2                     Angola  2013 -7.120017e+09
# 3                    Albania  2013  1.254151e+09
# 4     Emiratos Árabes Unidos  2013  9.764915e+09
# ...                      ...   ...           ...
# 1975                  Kosovo  2022  7.641623e+08
# 1976                   Yemen  2022           NaN
# 1977               Sudáfrica  2022  9.194808e+09
# 1978                  Zambia  2022 -6.511886e+07
# 1979                Zimbabwe  2022  3.415000e+08
#
# [1980 rows x 3 columns]

# %%
df_ied.sort_values(by=["Country Name", "Año"], inplace=True)
df_ied
# Out:
#      Country Name   Año           IED
# 1      Afganistán  2013  4.831135e+07
# 199    Afganistán  2014  4.297526e+07
# 397    Afganistán  2015  1.691466e+08
# 595    Afganistán  2016  9.359132e+07
# 793    Afganistán  2017  5.153390e+07
# ...           ...   ...           ...
# 1187     Zimbabwe  2018  7.178653e+08
# 1385     Zimbabwe  2019  2.495000e+08
# 1583     Zimbabwe  2020  1.503600e+08
# 1781     Zimbabwe  2021  2.500000e+08
# 1979     Zimbabwe  2022  3.415000e+08
#
# [1980 rows x 3 columns]

# %%
merged_df4.dtypes
# Out:
# Country Name                 object
# Año                          object
# Crecimiento_GDP(%)          float64
# Inflacion Anual(%)          float64
# Saldo Cuenta Corriente      float64
# Reservas Internacionales    float64
# Tipo de cambio Nominal      float64
# dtype: object

# %%
df_ied.dtypes
# Out:
# Country Name     object
# Año               int64
# IED             float64
# dtype: object

# %%
df_ied["Año"]=df_ied["Año"].astype(object)
df_ied.dtypes
# Out:
# Country Name     object
# Año              object
# IED             float64
# dtype: object

# %%
df_ied["Año"]=df_ied["Año"].astype(str)

# %%
df_riesgo_economico = pd.merge(df_6, df_ied, on=["Country Name", "Año"])
df_riesgo_economico
# Out:
#     Country Name   Año  Crecimiento_GDP(%)  Inflacion Anual(%)  \
# 0        Albania  2013            1.002018            1.937621
# 1        Albania  2014            1.774449            1.625865
# 2        Albania  2015            2.218726            1.896174
# 3        Albania  2016            3.314981            1.275432
# 4        Albania  2017            3.802599            1.986661
# ..           ...   ...                 ...                 ...
# 977      Vanuatu  2016            4.688756            0.842069
# 978      Vanuatu  2017            6.317305            3.084526
# 979      Vanuatu  2018            2.900230            2.330964
# 980      Vanuatu  2019            3.241188            2.762520
# 981      Vanuatu  2020           -4.992491            5.329351
#
#      Saldo Cuenta Corriente  Reservas Internacionales  Tipo de cambio Nominal  \
# 0             -1.184891e+09              2.773278e+09              105.669167
# ...

# %%
df_riesgo_economico["Country Name"].nunique()
# Out:
# 99

# %%
import os

# Join parts of a path
path = os.path.join('/Users/rodri/Desktop/Proyecto final/Datos', "df_riesgo_economico.csv")

# Get the directory name
dir_name = os.path.dirname(path)

# Get the base name
base_name = os.path.basename(path)

# Check if a path exists
path_exists = os.path.exists(path)

# Split a path into directory and file
dir_name, file_name = os.path.split(path)

# Get the absolute path
abs_path = os.path.abspath(path)

# %%
file_path=('/Users/rodri/Desktop/Proyecto final/Datos', 'df_riesgo_economico.csv')

# %%
df_riesgo_economico.to_csv(path,index=False)
